# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backer_info_df = pd.read_csv("backer_info.csv")
backer_info_df.head()
# Out:
#                                                                                           backer_info
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}

# %%
# Iterate through the backers DataFrame and convert each row to a dictionary.
values = []
column_names = []

for i,row in backer_info_df.iterrows():
    data = row[0]
    converted_data = json.loads(data)
    
    # Iterate through each dictionary (row) and get the values for each row using list comprehension.
    columns = [k for k,v in converted_data.items()]
    row_values = [v for k, v in converted_data.items()]
    
    # Append the list of values for each row to a list. 
    column_names.append(columns)
    values.append(row_values)

# Print out the list of values for each row.
for item in values:
    print(item)
# Out:
# ['av166', 968, 'Angelo Vincent', 'avincent@live.com']
# ['ha127', 563, 'Hubert Arnold', 'harnold@yandex.com']
# ['lg794', 65, 'Loris Goulet', 'lgoulet@yandex.com']
# ['tb566', 563, 'Teodora Brunelli', 'tbrunelli@outlook.com']
# ['lh506', 563, 'Lexie Hunt', 'lhunt@live.com']
# ['lh382', 563, 'Lambert Huber', 'lhuber@live.com']
# ['em444', 563, 'Emmy Morin', 'emorin@live.com']
# ['at582', 1572, 'Armonda Trani', 'atrani@live.com']
# ['id772', 1911, 'Ilana Duke', 'iduke@outlook.com']
# ['lw275', 65, 'Leigha Wright', 'lwright@live.com']
# ['ub509', 65, 'Uwe Becker', 'ubecker@yahoo.com']
# ['ha915', 1572, 'Hawa Audy', 'haudy@gmail.com']
# ['bb881', 968, 'Bia Bonura', 'bbonura@yahoo.com']
# ['mg332', 65, 'Michel Garner', 'mgarner@protonmail.com']
# ['kd700', 1572, 'Karole Dunn', 'kdunn@yahoo.com']
# ['as695', 563, 'Arndt Schreiber', 'aschreiber@yahoo.com']
# ['iv513', 65, 'Imen Villeneuve', 'ivilleneuve@yahoo.com']
# ['ab842', 65, 'Alcina Bonadonna', 'abonadonna@yandex.com']
# ['re181', 1114, 'Raelene Espinoza', 'respinoza@outlook.com']
# ['kn133', 65, 'Kati Nash', 'knash@protonmail.com']
# ['gj893', 65, 'Georg Jager', 'gjager@yahoo.com']
# ['vp915', 948, 'Virgilio Paolella', 'vpaolella@gmail.com']
# ['ja995', 563, 'Jerrica Avila', 'javila@protonmail.com']
# ['ga249', 563, 'Gianni Achterberg', 'gachterberg@live.com']
# ['td403', 65, 'Timoteo Dion', 'tdion@gmail.com']
# ['tv463', 1572, 'Teodoro Verno', 'tverno@yandex.com']
# ['mw606', 65, 'Morris Waller', 'mwaller@protonmail.com']
# ['hc648', 65, 'Hans Chen', 'hchen@yandex.com']
# ['ta379', 563, 'Trilby Auer', 'tauer@yahoo.com']
# ['tj583', 1572, 'Theola Jodoin', 'tjodoin@yandex.com']
# ['tc559', 65, 'Tova Capri', 'tcapri@live.com']
# ['ww629', 65, 'Wanda Walton', 'wwalton@protonmail.com']
# ['jg155', 1572, 'Justine Gill', 'jgill@yahoo.com']
# ['jd328', 1911, 'Julee Doyle', 'jdoyle@gmail.com']
# ['ld239', 65, 'Lisbeth Deliso', 'ldeliso@gmail.com']
# ['cv918', 968, 'Carl Valdez', 'cvaldez@gmail.com']
# ['kb145', 563, 'Kelyan Butler', 'kbutler@yahoo.com']
# ['dw578', 65, 'Donat Weber', 'dweber@live.com']
# ['ad511', 65, 'Alethia Delorme', 'adelorme@outlook.com']
# ['db633', 65, 'Darrell Bernardi', 'dbernardi@yandex.com']
# ['cr369', 65, 'Carina Reeves', 'creeves@gmail.com']
# ['mr978', 65, 'Marvin Ruiz', 'mruiz@outlook.com']
# ['md167', 1572, 'Mariabella Duerr', 'mduerr@live.com']
# ['jr877', 1572, 'Jeni Ricco', 'jricco@live.com']
# ['om753', 65, 'Otto Munoz', 'omunoz@yahoo.com']
# ['ng231', 1114, 'Nesrine Gensch', 'ngensch@yandex.com']
# ['tl316', 65, 'Tullio Lejeune', 'tlejeune@outlook.com']
# ['dl139', 563, 'Dreama Lonardo', 'dlonardo@live.com']
# ['mw253', 968, 'Maryrose West', 'mwest@live.com']
# ['im424', 65, 'Irina Mays', 'imays@yandex.com']
# ['mb131', 968, 'Marcelo Brose', 'mbrose@protonmail.com']
# ['nc240', 1572, 'Nestor Coutant', 'ncoutant@gmail.com']
# ['ab318', 1572, 'Aloysius Braun', 'abraun@live.com']
# ['af301', 65, 'Amos Ferre', 'aferre@gmail.com']
# ['bl736', 563, 'Brigitte Lynch', 'blynch@outlook.com']
# ['ar957', 65, 'Alegra Ramsey', 'aramsey@yahoo.com']
# ['cb474', 968, 'Conchita Beitel', 'cbeitel@gmail.com']
# ['dv246', 1572, 'Donnie Vernet', 'dvernet@protonmail.com']
# ['cj111', 563, 'Cyril Jones', 'cjones@protonmail.com']
# ['lh765', 563, 'Lucinda Hays', 'lhays@outlook.com']
# ['wh697', 65, 'Walter Hermann', 'whermann@outlook.com']
# ['eb714', 65, 'Emil Blanc', 'eblanc@protonmail.com']
# ['ec356', 1572, 'Eldwin Cesare', 'ecesare@protonmail.com']
# ['yh129', 65, 'Yusuf Hudson', 'yhudson@protonmail.com']
# ['as494', 65, 'Arrigo Salazar', 'asalazar@gmail.com']
# ['lb146', 563, 'Levi Beck', 'lbeck@gmail.com']
# ['cc470', 563, 'Celinda Caillet', 'ccaillet@yandex.com']
# ['mm239', 563, 'Marcus Medici', 'mmedici@gmail.com']
# ['dg360', 65, 'Daysi Gamble', 'dgamble@yahoo.com']
# ['rh399', 1572, 'Rory Hildebrand', 'rhildebrand@yahoo.com']
# ['hr430', 65, 'Heini Raffin', 'hraffin@yahoo.com']
# ['ar829', 65, 'Anna Randall', 'arandall@outlook.com']
# ['sw301', 65, 'Sharmaine Weber', 'sweber@yahoo.com']
# ['rr355', 65, 'Ranee Renault', 'rrenault@outlook.com']
# ['zc515', 1572, 'Zak Cianciola', 'zcianciola@yahoo.com']
# ['gp101', 65, 'Granville Potts', 'gpotts@gmail.com']
# ['bm741', 65, 'Bo Marsh', 'bmarsh@live.com']
# ['jd148', 65, 'Jay Duerr', 'jduerr@yahoo.com']
# ['mm632', 65, 'Milla Morin', 'mmorin@yahoo.com']
# ['ls884', 65, 'Leanne Savage', 'lsavage@gmail.com']
# ['sp364', 968, 'Silvana Patton', 'spatton@live.com']
# ['hh963', 65, 'Harvey Hoch', 'hhoch@outlook.com']
# ['sb272', 65, 'Seth Berthier', 'sberthier@protonmail.com']
# ['et566', 1114, 'Eugen Trani', 'etrani@protonmail.com']
# ['sd421', 1572, 'Santina Dieter', 'sdieter@yahoo.com']
# ['tg563', 65, 'Trinh Gregoire', 'tgregoire@live.com']
# ['kc571', 968, 'Karin Celano', 'kcelano@yandex.com']
# ['sd121', 1114, 'Sofia Decker', 'sdecker@yahoo.com']
# ['sk744', 65, 'Sherise Keller', 'skeller@outlook.com']
# ['km642', 65, 'Kirby Michel', 'kmichel@gmail.com']
# ['fu320', 65, 'Florentine Ungaro', 'fungaro@yandex.com']
# ['ld180', 1911, 'Louise Dejesus', 'ldejesus@yandex.com']
# ['ds377', 65, 'Daniele Suarez', 'dsuarez@yahoo.com']
# ['bb692', 65, 'Beckie Buchholz', 'bbuchholz@live.com']
# ['wd557', 563, 'William Dickson', 'wdickson@yandex.com']
# ['jd905', 65, 'Jolie Daugherty', 'jdaugherty@gmail.com']
# ['dd770', 65, 'Detta Dressler', 'ddressler@yahoo.com']
# ['cv698', 238, 'Clifton Villette', 'cvillette@outlook.com']
# ['cn307', 968, 'Cythia Netti', 'cnetti@outlook.com']
# ['eb198', 1572, 'Elsbeth Butler', 'ebutler@yahoo.com']
# ['am869', 65, 'Ambrine Mann', 'amann@yahoo.com']
# ['gr400', 1911, 'Gerald Robert', 'grobert@protonmail.com']
# ['az657', 563, 'Assunta Zezza', 'azezza@live.com']
# ['kc598', 1572, 'Kerstin Campbell', 'kcampbell@protonmail.com']
# ['lb588', 65, 'Lino Brock', 'lbrock@outlook.com']
# ['rl866', 65, 'Rubie Levasseur', 'rlevasseur@gmail.com']
# ['jf340', 65, 'Johann Flowers', 'jflowers@live.com']
# ['tb384', 1572, 'Thibaud Bullock', 'tbullock@yahoo.com']
# ['dg290', 65, 'Dan Gallois', 'dgallois@outlook.com']
# ['rr518', 65, 'Rolf Richards', 'rrichards@live.com']
# ['sh779', 968, 'Selyan Hoffman', 'shoffman@outlook.com']
# ['lw525', 65, 'Lucca Weber', 'lweber@live.com']
# ['sl474', 563, 'Sydney Louvet', 'slouvet@gmail.com']
# ['dp154', 65, 'Dusty Paola', 'dpaola@outlook.com']
# ['id770', 238, 'Ilario Dressler', 'idressler@protonmail.com']
# ['ek669', 65, 'Emile Khan', 'ekhan@outlook.com']
# ['eb945', 65, 'Elliot Bonomo', 'ebonomo@yandex.com']
# ['ag917', 1114, 'Arvin Golden', 'agolden@yandex.com']
# ['ac437', 563, 'Ampelio Cabrera', 'acabrera@live.com']
# ['sf583', 1572, 'Somer Fuhrmann', 'sfuhrmann@yahoo.com']
# ['sa973', 65, 'Shanti Allard', 'sallard@yandex.com']
# ['kc836', 65, 'Konstanze Caroselli', 'kcaroselli@yandex.com']
# ['bt844', 65, 'Bellarmine Taylor', 'btaylor@outlook.com']
# ['mf392', 65, 'Matthew Fischer', 'mfischer@live.com']
# ['dh568', 65, 'Dan Hoffmann', 'dhoffmann@yandex.com']
# ['iv880', 968, 'Imelda Vallee', 'ivallee@gmail.com']
# ['gl219', 1572, 'Giancarlo Lindsey', 'glindsey@protonmail.com']
# ['kb890', 1572, 'Kris Brennan', 'kbrennan@protonmail.com']
# ['jf901', 65, 'Johnnie Fux', 'jfux@gmail.com']
# ['ja340', 1114, 'Janeth Adam', 'jadam@protonmail.com']
# ['ar906', 65, 'Agata Rosa', 'arosa@yahoo.com']
# ['dc579', 65, 'Dennise Cabrera', 'dcabrera@live.com']
# ['gg660', 65, 'Garret Geier', 'ggeier@yahoo.com']
# ['db112', 65, 'Delia Beguin', 'dbeguin@yandex.com']
# ['ld487', 65, 'Louanne Damiani', 'ldamiani@outlook.com']
# ['bj475', 1572, 'Bronze Jenkins', 'bjenkins@protonmail.com']
# ['mc838', 65, 'Mila Coffey', 'mcoffey@protonmail.com']
# ['he768', 65, 'Hank Essert', 'hessert@gmail.com']
# ['pm973', 65, 'Paulina Marais', 'pmarais@protonmail.com']
# ['bf986', 65, 'Beatrice Fulco', 'bfulco@gmail.com']
# ['sb322', 65, 'Sudie Burgess', 'sburgess@yandex.com']
# ['ps571', 563, 'Prince Suarez', 'psuarez@yahoo.com']
# ['mb333', 1572, 'Mitzi Biermann', 'mbiermann@gmail.com']
# ['ab290', 1572, 'Aminata Bru', 'abru@yahoo.com']
# ['jm190', 968, 'Jina Magrino', 'jmagrino@live.com']
# ['rg933', 65, 'Rosena Gould', 'rgould@gmail.com']
# ['ik787', 1572, 'Issac Kline', 'ikline@live.com']
# ['rl982', 65, 'Roderica Lehmann', 'rlehmann@gmail.com']
# ['ac179', 65, 'Ariah Comte', 'acomte@yandex.com']
# ['eg193', 238, 'Ellis Gamble', 'egamble@yahoo.com']
# ['fl258', 65, 'Friedrich Lott', 'flott@yandex.com']
# ['mb203', 1114, 'Marilou Beutel', 'mbeutel@gmail.com']
# ['en399', 65, 'Elene Navarro', 'enavarro@yahoo.com']
# ['mr756', 968, 'Mac Raffin', 'mraffin@yahoo.com']
# ['sc271', 563, 'Shona Carr', 'scarr@outlook.com']
# ['xg684', 1572, 'Ximena Guy', 'xguy@protonmail.com']
# ['ab829', 563, 'Arnaud Becker', 'abecker@live.com']
# ['fd404', 65, 'Fiore Desautels', 'fdesautels@live.com']
# ['rm849', 563, 'Robby Mccray', 'rmccray@gmail.com']
# ['lr658', 65, 'Louis Rush', 'lrush@protonmail.com']
# ['sh994', 65, 'Serena Holzknecht', 'sholzknecht@protonmail.com']
# ['zv654', 65, 'Zan Verdier', 'zverdier@yahoo.com']
# ['hb861', 1572, 'Hipolito Baldocchi', 'hbaldocchi@gmail.com']
# ['hb280', 65, 'Hollis Barnett', 'hbarnett@live.com']
# ['be560', 65, 'Barend Edwards', 'bedwards@yandex.com']
# ['lh820', 563, 'Loane Holst', 'lholst@live.com']
# ['zp659', 1572, 'Zeno Pruneau', 'zpruneau@gmail.com']
# ['de758', 1114, 'Devon Epifano', 'depifano@protonmail.com']
# ['jb896', 65, 'Jarrett Barrera', 'jbarrera@gmail.com']
# ['wb355', 238, 'Walburg Burris', 'wburris@outlook.com']
# ['rd560', 65, 'Raffaela Darras', 'rdarras@gmail.com']
# ['er574', 1572, 'Eli Resta', 'eresta@outlook.com']
# ['jc163', 65, 'Jin Chen', 'jchen@outlook.com']
# ['kb942', 1114, 'Katja Butler', 'kbutler@protonmail.com']
# ['af969', 563, 'Allegra Fiedler', 'afiedler@yandex.com']
# ['bp212', 1572, 'Benton Pereira', 'bpereira@live.com']
# ['tc947', 65, 'Tesha Carpinello', 'tcarpinello@outlook.com']
# ['ak106', 1572, 'Anneli Kaufman', 'akaufman@outlook.com']
# ['mr294', 1572, 'Merle Rowe', 'mrowe@yahoo.com']
# ['bb365', 65, 'Bev Bellotti', 'bbellotti@yandex.com']
# ['bj274', 65, 'Blake Jenkins', 'bjenkins@outlook.com']
# ['qw345', 1572, 'Qiana Washington', 'qwashington@gmail.com']
# ['ra925', 65, 'Rayane Adam', 'radam@live.com']
# ['pg824', 968, 'Petronella Guilbaud', 'pguilbaud@outlook.com']
# ['ef414', 65, 'Elodia Forgione', 'eforgione@gmail.com']
# ['rp650', 238, 'Ryan Potts', 'rpotts@protonmail.com']
# ['se972', 1114, 'Sigmund Everett', 'severett@yahoo.com']
# ['sd958', 65, 'Serafina Desroches', 'sdesroches@yahoo.com']
# ['mb304', 65, 'Murray Barrese', 'mbarrese@yandex.com']
# ['lr409', 563, 'Luis Roberts', 'lroberts@protonmail.com']
# ['fm559', 65, 'Felicia Mcneil', 'fmcneil@outlook.com']
# ['wd714', 65, 'Willette Dattoli', 'wdattoli@outlook.com']
# ['ls638', 1572, 'Lucas Stephens', 'lstephens@protonmail.com']
# ['am362', 65, 'Amo Moses', 'amoses@outlook.com']
# ['ta190', 563, 'Tandy Acker', 'tacker@outlook.com']
# ['rb753', 65, 'Rolf Biron', 'rbiron@outlook.com']
# ['cc594', 65, 'Catharina Cappella', 'ccappella@gmail.com']
# ['vh915', 65, 'Virgilio Hyde', 'vhyde@live.com']
# ['og539', 65, 'Ollie Gwerder', 'ogwerder@yandex.com']
# ['dd470', 1911, 'Daniela Demers', 'ddemers@yahoo.com']
# ['ap718', 238, 'Angel Peragine', 'aperagine@live.com']
# ['vw158', 1572, 'Vicenzo Wells', 'vwells@yandex.com']
# ['fh696', 2284, 'Fernanda Hodges', 'fhodges@yandex.com']
# ['df617', 968, 'Darrin Fiedler', 'dfiedler@yahoo.com']
# ['jv716', 65, 'Janine Veronesi', 'jveronesi@gmail.com']
# ['tc807', 65, 'Terenzio Carver', 'tcarver@gmail.com']
# ['me460', 563, 'Magali Eilerts', 'meilerts@gmail.com']
# ['kp942', 1572, 'Kimber Puech', 'kpuech@protonmail.com']
# ['xp438', 563, 'Xenia Pergola', 'xpergola@yandex.com']
# ['af564', 1572, 'Arlena Fox', 'afox@protonmail.com']
# ['wn746', 1114, 'Wilfred Nazzaro', 'wnazzaro@yahoo.com']
# ['ad641', 1572, 'Angelina Decker', 'adecker@yahoo.com']
# ['rs660', 65, 'Ressie Schneider', 'rschneider@live.com']
# ['dp520', 65, 'Daine Pruneau', 'dpruneau@outlook.com']
# ['me520', 65, 'Marius Emilio', 'memilio@gmail.com']
# ['es977', 1572, 'Emily Stout', 'estout@gmail.com']
# ['sd883', 3138, 'Shaunna Dreher', 'sdreher@yahoo.com']
# ['tb283', 65, 'Toi Briere', 'tbriere@outlook.com']
# ['eb415', 65, 'Eliodoro Black', 'eblack@yahoo.com']
# ['fb116', 1572, 'Faustino Burgstaller', 'fburgstaller@outlook.com']
# ['jb391', 1572, 'Jeramy Benard', 'jbenard@yandex.com']
# ['ac624', 563, 'Annika Curtis', 'acurtis@live.com']
# ['kc104', 65, 'Kelia Campbell', 'kcampbell@protonmail.com']
# ['dg582', 65, 'Dario Gerst', 'dgerst@protonmail.com']
# ['mb933', 1572, 'Maryetta Bussa', 'mbussa@yahoo.com']
# ['em898', 65, 'Emerich Mccoy', 'emccoy@live.com']
# ['tw982', 968, 'Timothe Wilder', 'twilder@yandex.com']
# ['ab575', 65, 'Amadore Breitbarth', 'abreitbarth@protonmail.com']
# ['dg744', 1572, 'Dave Gaillard', 'dgaillard@live.com']
# ['cj442', 1572, 'Catrin Joseph', 'cjoseph@live.com']
# ['lo117', 65, 'Laverne Ortega', 'lortega@yandex.com']
# ['bg270', 65, 'Bulah Guay', 'bguay@yandex.com']
# ['jc692', 65, 'Jae Castellucci', 'jcastellucci@yahoo.com']
# ['jf750', 1572, 'Joseph Freeman', 'jfreeman@live.com']
# ['lr317', 968, 'Lena Robbins', 'lrobbins@live.com']
# ['cp253', 65, 'Charley Petitjean', 'cpetitjean@yandex.com']
# ['vv330', 65, 'Veronika Vesco', 'vvesco@live.com']
# ['ch724', 1572, 'Calandra Hofmeister', 'chofmeister@protonmail.com']
# ['dm121', 65, 'Devon Marques', 'dmarques@yandex.com']
# ['lc141', 65, 'Leon Carson', 'lcarson@gmail.com']
# ['am966', 65, 'Adelrico Meadows', 'ameadows@gmail.com']
# ['ab249', 65, 'Adel Becke', 'abecke@yahoo.com']
# ['mb828', 65, 'Mariya Babin', 'mbabin@outlook.com']
# ['pu317', 65, 'Peg Urciuoli', 'purciuoli@yandex.com']
# ['cb515', 1572, 'Clarita Barron', 'cbarron@protonmail.com']
# ['so203', 563, 'Silvia Olson', 'solson@gmail.com']
# ['aa284', 65, 'Armand Arnold', 'aarnold@live.com']
# ['sc143', 65, 'Sueann Casciani', 'scasciani@outlook.com']
# ['je217', 65, 'Jc Elliott', 'jelliott@yandex.com']
# ['ke511', 1114, 'Kalet Eaton', 'keaton@outlook.com']
# ['oa673', 563, 'Ottavia Abraham', 'oabraham@yandex.com']
# ['sc432', 968, 'Swanhild Cameron', 'scameron@yandex.com']
# ['aj655', 65, 'Alessandrina Jollenbeck', 'ajollenbeck@outlook.com']
# ['jp351', 968, 'Jamison Perona', 'jperona@live.com']
# ['lj758', 968, 'Louis Justice', 'ljustice@yahoo.com']
# ['ps794', 1572, 'Pablo Sykes', 'psykes@yandex.com']
# ['nb202', 1572, 'Nek Blecher', 'nblecher@yahoo.com']
# ['gp356', 968, 'Guadalupe Pannone', 'gpannone@outlook.com']
# ['rb945', 1572, 'Ramona Berg', 'rberg@yandex.com']
# ['gw991', 65, 'Gioconda Webster', 'gwebster@live.com']
# ['gb896', 910, 'George Bauers', 'gbauers@yahoo.com']
# ['jm345', 563, 'Julian Maillot', 'jmaillot@yandex.com']
# ['ma565', 1911, 'Melusina Asti', 'masti@yandex.com']
# ['oh728', 65, 'Ornella Hester', 'ohester@live.com']
# ['dg119', 1572, 'Dione Gass', 'dgass@yandex.com']
# ['kd744', 968, 'Konrad Damone', 'kdamone@yandex.com']
# ['ww138', 65, 'Walid Woods', 'wwoods@protonmail.com']
# ['gb135', 1572, 'Giana Blevins', 'gblevins@protonmail.com']
# ['lp541', 563, 'Lino Pires', 'lpires@yandex.com']
# ['hm752', 65, 'Helmina Mosco', 'hmosco@outlook.com']
# ['ib452', 1911, 'Inaya Barton', 'ibarton@yandex.com']
# ['fc303', 65, 'Francesca Chambers', 'fchambers@protonmail.com']
# ['kb141', 1114, 'Kenisha Bergfalk', 'kbergfalk@outlook.com']
# ['is909', 65, 'Ismael Sarrazin', 'isarrazin@live.com']
# ['hv133', 968, 'Holger Vitiello', 'hvitiello@protonmail.com']
# ['nm163', 65, 'Nayla Melendez', 'nmelendez@yahoo.com']
# ['cs899', 65, 'Camila Sciarretta', 'csciarretta@yandex.com']
# ['lh190', 65, 'Lucia Hatfield', 'lhatfield@gmail.com']
# ['as260', 65, 'Annetta Scholz', 'ascholz@live.com']
# ['db149', 65, 'Demarcus Barthelemy', 'dbarthelemy@gmail.com']
# ['cg952', 563, 'Clifton Garibaldi', 'cgaribaldi@live.com']
# ['tm490', 65, 'Tobias Mcintyre', 'tmcintyre@gmail.com']
# ['lt569', 65, 'Lalie Tyler', 'ltyler@outlook.com']
# ['ce212', 65, 'Cristiano Everhart', 'ceverhart@yandex.com']
# ['sr285', 2284, 'Shirl Rochon', 'srochon@live.com']
# ['tc231', 2882, 'Treena Ciampa', 'tciampa@yandex.com']
# ['ll471', 968, 'Luther Leonard', 'lleonard@gmail.com']
# ['aa130', 65, 'Affonso Abraham', 'aabraham@outlook.com']
# ['sb241', 563, 'So Boilard', 'sboilard@yandex.com']
# ['lb909', 968, 'Luther Barberi', 'lbarberi@yahoo.com']
# ['lw976', 910, 'Leuther Webb', 'lwebb@gmail.com']
# ['ab143', 1114, 'Abel Burke', 'aburke@outlook.com']
# ['cg893', 65, 'Calogero Geiger', 'cgeiger@outlook.com']
# ['nl492', 65, 'Nelson Lemire', 'nlemire@yahoo.com']
# ['nc285', 1572, 'Nadene Cartelli', 'ncartelli@live.com']
# ['ct703', 65, 'Calvin Tate', 'ctate@yandex.com']
# ['aw876', 1572, 'Axel Watts', 'awatts@protonmail.com']
# ['af506', 563, 'Alda Feigenbaum', 'afeigenbaum@live.com']
# ['es282', 65, 'Elena Shields', 'eshields@outlook.com']
# ['co633', 65, 'Circinus Odom', 'codom@yahoo.com']
# ['mh163', 65, 'Marietta Holzmann', 'mholzmann@yandex.com']
# ['pc978', 65, 'Peg Corriveau', 'pcorriveau@protonmail.com']
# ['gc386', 2882, 'Gregory Cianciolo', 'gcianciolo@live.com']
# ['nl252', 1114, 'Nolhan Lindsey', 'nlindsey@live.com']
# ['rb829', 1572, 'Romero Blau', 'rblau@gmail.com']
# ['gl884', 65, 'Genaro Larose', 'glarose@yahoo.com']
# ['og404', 65, 'Oralee Garbarino', 'ogarbarino@live.com']
# ['kr745', 1911, 'Karsten Riggs', 'kriggs@live.com']
# ['jc104', 238, 'Joris Cline', 'jcline@yandex.com']
# ['th958', 968, 'Tasha Holzknecht', 'tholzknecht@live.com']
# ['jb207', 65, 'Jarrett Beaumont', 'jbeaumont@yandex.com']
# ['lm386', 65, 'Laverne Maddalone', 'lmaddalone@yahoo.com']
# ['ic277', 968, 'Imre Carlson', 'icarlson@live.com']
# ['ab714', 968, 'Angel Brennan', 'abrennan@live.com']
# ['jm813', 2488, 'Jinny Michaud', 'jmichaud@live.com']
# ['ma226', 238, 'Maryam Armellino', 'marmellino@outlook.com']
# ['lm154', 1114, 'Lyle Massey', 'lmassey@yandex.com']
# ['pp209', 65, 'Peppe Pohl', 'ppohl@gmail.com']
# ['ss320', 1114, 'Shakita Sabatier', 'ssabatier@gmail.com']
# ['lb805', 1572, 'Lynwood Bozza', 'lbozza@yahoo.com']
# ['sf196', 968, 'Siglinde Flores', 'sflores@live.com']
# ['jc350', 1572, 'Jaden Castro', 'jcastro@outlook.com']
# ['bh958', 1114, 'Bartolo Haupt', 'bhaupt@outlook.com']
# ['vp800', 65, 'Venetta Perugini', 'vperugini@gmail.com']
# ['ec148', 1572, 'Ellsworth Clements', 'eclements@yahoo.com']
# ['ha431', 65, 'Harbin Alston', 'halston@outlook.com']
# ['sw972', 65, 'Syrine Walter', 'swalter@yahoo.com']
# ['sb891', 1572, 'Sansone Bisaillon', 'sbisaillon@protonmail.com']
# ['sf735', 1114, 'Shantay Fiori', 'sfiori@protonmail.com']
# ['mp538', 563, 'Mary Prince', 'mprince@protonmail.com']
# ['cf904', 1572, 'Catrin Ferguson', 'cferguson@gmail.com']
# ['gs818', 1572, 'Gianpiero Samson', 'gsamson@yandex.com']
# ['ra782', 1572, 'Robert Altieri', 'raltieri@protonmail.com']
# ['yc752', 1911, 'Yvone Capodanno', 'ycapodanno@live.com']
# ['le377', 563, 'Lucetta Eichel', 'leichel@protonmail.com']
# ['ja139', 968, 'Jalisa Anastasi', 'janastasi@yandex.com']
# ['jf881', 65, 'Jessi Farley', 'jfarley@yahoo.com']
# ['am638', 1114, 'Adolph Merrill', 'amerrill@gmail.com']
# ['rh663', 65, 'Riyad Holst', 'rholst@outlook.com']
# ['dl438', 238, 'Donatien Lefrancois', 'dlefrancois@yandex.com']
# ['je184', 1114, 'Jere Evans', 'jevans@outlook.com']
# ['xg938', 65, 'Xandi Glenn', 'xglenn@live.com']
# ['mg208', 563, 'Marianne Geiger', 'mgeiger@outlook.com']
# ['ag672', 65, 'Alonzo Gautier', 'agautier@protonmail.com']
# ['sc991', 65, 'Santo Cornacchia', 'scornacchia@yahoo.com']
# ['ar456', 238, 'Aleida Robertson', 'arobertson@yahoo.com']
# ['an122', 65, 'Alexandra Nolan', 'anolan@yandex.com']
# ['mh749', 65, 'Marina Habich', 'mhabich@protonmail.com']
# ['ac765', 65, 'Agnella Cloutier', 'acloutier@yahoo.com']
# ['ln560', 563, 'Loralee Nerone', 'lnerone@live.com']
# ['dm881', 1114, 'Dot Moore', 'dmoore@protonmail.com']
# ['wm699', 65, 'Wolf Morin', 'wmorin@gmail.com']
# ['ca628', 1114, 'Ciel Augustin', 'caugustin@yandex.com']
# ['ls538', 1114, 'Leontina Saucier', 'lsaucier@live.com']
# ['kr958', 563, 'Kathern Rodriquez', 'krodriquez@live.com']
# ['ad265', 65, 'Alder Dressler', 'adressler@outlook.com']
# ['am627', 1572, 'Aroghetto Manza', 'amanza@yahoo.com']
# ['rp666', 1572, 'Roberto Perry', 'rperry@gmail.com']
# ['rs221', 65, 'Reena Shaw', 'rshaw@protonmail.com']
# ['ma490', 65, 'Melina Abeln', 'mabeln@yandex.com']
# ['xd210', 65, 'Xavier Delahaye', 'xdelahaye@yahoo.com']
# ['mc413', 563, 'Moses Cece', 'mcece@protonmail.com']
# ['ss568', 1572, 'Sheilah Shaw', 'sshaw@yandex.com']
# ['dr174', 563, 'Daniela Rhodes', 'drhodes@gmail.com']
# ['vb927', 563, 'Viviana Belhumeur', 'vbelhumeur@protonmail.com']
# ['ms327', 65, 'Mireille Stanley', 'mstanley@protonmail.com']
# ['lf675', 1911, 'Lynetta Frank', 'lfrank@live.com']
# ['hb499', 65, 'Hermann Buckholtz', 'hbuckholtz@gmail.com']
# ['lb187', 65, 'Leane Boulanger', 'lboulanger@outlook.com']
# ['um200', 65, 'Ugo Mammone', 'umammone@yahoo.com']
# ['gh932', 65, 'Gail Hewitt', 'ghewitt@outlook.com']
# ['kl672', 65, 'Kermit Lowery', 'klowery@gmail.com']
# ['ab491', 563, 'Alois Behrend', 'abehrend@live.com']
# ['bb348', 1572, 'Bonito Bon', 'bbon@live.com']
# ['jv337', 2882, 'Jacinda Verde', 'jverde@yahoo.com']
# ['lh149', 65, 'Lloyd Holden', 'lholden@outlook.com']
# ['kw599', 3138, 'Kurigunde Wolfe', 'kwolfe@protonmail.com']
# ['mh683', 65, 'Marvin Hummel', 'mhummel@yahoo.com']
# ['bm342', 65, 'Baiardo Maglione', 'bmaglione@gmail.com']
# ['il539', 1114, 'Isaias Lyons', 'ilyons@yahoo.com']
# ['jl327', 563, 'Johnnie Le', 'jle@protonmail.com']
# ['wf249', 65, 'Walker Friedrich', 'wfriedrich@live.com']
# ['ba539', 1572, 'Benedict Allen', 'ballen@protonmail.com']
# ['sj553', 563, 'Sung Jordan', 'sjordan@gmail.com']
# ['gb371', 563, 'Garfield Bonnard', 'gbonnard@yahoo.com']
# ['hm715', 1572, 'Hansel Mecca', 'hmecca@outlook.com']
# ['ec905', 1114, 'Emy Chapman', 'echapman@gmail.com']
# ['lw634', 65, 'Lucetta Wilcox', 'lwilcox@outlook.com']
# ['dh507', 65, 'Danial Hummel', 'dhummel@yahoo.com']
# ['mr622', 65, 'Marion Ribeiro', 'mribeiro@gmail.com']
# ['gs461', 1572, 'Gilbert Spaziani', 'gspaziani@gmail.com']
# ['gb648', 563, 'Genevra Bentley', 'gbentley@gmail.com']
# ['eo125', 563, 'Emilio Owen', 'eowen@yahoo.com']
# ['rb185', 1572, 'Reid Borchard', 'rborchard@gmail.com']
# ['og865', 563, 'Oscar Gallant', 'ogallant@live.com']
# ['tr733', 563, 'Titouan Reginato', 'treginato@live.com']
# ['ac323', 65, 'Aniella Coleman', 'acoleman@yandex.com']
# ['lo326', 1911, 'Laurena Ortiz', 'lortiz@live.com']
# ['hc889', 563, 'Helaine Carignan', 'hcarignan@live.com']
# ['hv904', 65, 'Harold Vinci', 'hvinci@yandex.com']
# ['md370', 1114, 'Monte Dillon', 'mdillon@yandex.com']
# ['sb514', 1572, 'Shondra Bach', 'sbach@protonmail.com']
# ['sf324', 1572, 'Saul Fayolle', 'sfayolle@yahoo.com']
# ['eb537', 968, 'Etienne Buonopane', 'ebuonopane@live.com']
# ['bn189', 65, 'Beatrix Noble', 'bnoble@protonmail.com']
# ['sc931', 1114, 'Seema Cherry', 'scherry@protonmail.com']
# ['th234', 65, 'Toby Haupt', 'thaupt@gmail.com']
# ['lb460', 1114, 'Lamar Berger', 'lberger@yahoo.com']
# ['sp161', 563, 'Suzanne Paniccia', 'spaniccia@gmail.com']
# ['bm476', 238, 'Bianka Massey', 'bmassey@yandex.com']
# ['ta391', 563, 'Tomika Andrews', 'tandrews@protonmail.com']
# ['bm966', 1572, 'Bertha Maurin', 'bmaurin@protonmail.com']
# ['nm952', 1911, 'Nyla Mcconnell', 'nmcconnell@outlook.com']
# ['rg418', 65, 'Ronny Gotti', 'rgotti@gmail.com']
# ['rm381', 65, 'Rollin Magne', 'rmagne@yahoo.com']
# ['ab162', 65, 'Anae Buzzeo', 'abuzzeo@protonmail.com']
# ['gf246', 1114, 'Giada Fisher', 'gfisher@protonmail.com']
# ['ch750', 1114, 'Cletus Hatfield', 'chatfield@yandex.com']
# ['jg803', 1114, 'Jeffrey Gerber', 'jgerber@yahoo.com']
# ['pl955', 563, 'Philomena Leduc', 'pleduc@yandex.com']
# ['bc578', 968, 'Bellissa Carpenter', 'bcarpenter@yahoo.com']
# ['np469', 65, 'Nadene Pittman', 'npittman@yahoo.com']
# ['nj734', 65, 'Nakita Jourdain', 'njourdain@live.com']
# ['as672', 1114, 'Alger Spatafore', 'aspatafore@yahoo.com']
# ['lg912', 65, 'Luna Gallegos', 'lgallegos@live.com']
# ['rm719', 1114, 'Rosanna Mcbride', 'rmcbride@yahoo.com']
# ['kh931', 1114, 'Kali Haber', 'khaber@outlook.com']
# ['ml523', 65, 'Medwin Lazzaro', 'mlazzaro@live.com']
# ['df670', 1114, 'Dany Floyd', 'dfloyd@gmail.com']
# ['cs996', 968, 'Cristiana Stafford', 'cstafford@yahoo.com']
# ['wh607', 238, 'Warner Hermann', 'whermann@protonmail.com']
# ['jp523', 65, 'Javier Pearson', 'jpearson@yahoo.com']
# ['rw116', 563, 'Romano Whitehead', 'rwhitehead@protonmail.com']
# ['md744', 65, 'Marquis Dietrich', 'mdietrich@protonmail.com']
# ['df975', 65, 'Donovan Filiatrault', 'dfiliatrault@yandex.com']
# ['rl203', 563, 'Robert Lopardo', 'rlopardo@live.com']
# ['ab776', 65, 'Anael Beck', 'abeck@live.com']
# ['th710', 1572, 'Teofila Horn', 'thorn@protonmail.com']
# ['if257', 1572, 'Ishild Fusillo', 'ifusillo@outlook.com']
# ['ls716', 968, 'Lilas Suarez', 'lsuarez@yandex.com']
# ['bh265', 65, 'Beatrice Huffman', 'bhuffman@protonmail.com']
# ['bb194', 968, 'Bart Buhr', 'bbuhr@yahoo.com']
# ['sa754', 65, 'Sylvester Arnould', 'sarnould@gmail.com']
# ['jb318', 563, 'Joseph Berardinelli', 'jberardinelli@protonmail.com']
# ['ls852', 65, 'Lucca Stafford', 'lstafford@yandex.com']
# ['mf855', 968, 'Malvina Faerber', 'mfaerber@gmail.com']
# ['sg584', 1572, 'Sydney Guillard', 'sguillard@gmail.com']
# ['jg665', 238, 'Julie Garavaglia', 'jgaravaglia@yandex.com']
# ['ra144', 948, 'Raeann Atkins', 'ratkins@protonmail.com']
# ['ad490', 1572, 'Azucena Dresdner', 'adresdner@yandex.com']
# ['ab679', 65, 'Aminata Bonato', 'abonato@protonmail.com']
# ['mm395', 1572, 'Mariya Mays', 'mmays@gmail.com']
# ['tp337', 968, 'Trevor Prince', 'tprince@yahoo.com']
# ['li108', 563, 'Lamont Ingersleben', 'lingersleben@yandex.com']
# ['mb156', 65, 'Mirco Boisson', 'mboisson@protonmail.com']
# ['jc698', 1572, 'Jessica Camilli', 'jcamilli@protonmail.com']
# ['rm314', 65, 'Rodrigo Meadows', 'rmeadows@live.com']
# ['bm559', 563, 'Barrett Mcclain', 'bmcclain@yahoo.com']
# ['rj697', 1572, 'Rainer Jourdain', 'rjourdain@yahoo.com']
# ['eu931', 563, 'Edda Underwood', 'eunderwood@live.com']
# ['tf166', 65, 'Tad Fleming', 'tfleming@yandex.com']
# ['lb900', 65, 'Lindsey Beck', 'lbeck@live.com']
# ['kp905', 1572, 'Kirsten Poisson', 'kpoisson@yahoo.com']
# ['bm614', 65, 'Barney Morris', 'bmorris@protonmail.com']
# ['km622', 65, 'Kasi Merritt', 'kmerritt@live.com']
# ['bw202', 1572, 'Brunhilde Walter', 'bwalter@gmail.com']
# ['lb585', 1572, 'Lilly Billet', 'lbillet@gmail.com']
# ['ah247', 1572, 'Alfonzo Harris', 'aharris@yahoo.com']
# ['db600', 1114, 'Dorine Barrett', 'dbarrett@gmail.com']
# ['sb809', 65, 'Soraya Boudet', 'sboudet@protonmail.com']
# ['gm424', 563, 'Giambattista Mazzoni', 'gmazzoni@gmail.com']
# ['ch866', 65, 'Chanelle Hyde', 'chyde@protonmail.com']
# ['bh772', 563, 'Bradley Harrell', 'bharrell@yandex.com']
# ['ms428', 65, 'Minna Schuster', 'mschuster@gmail.com']
# ['ib835', 65, 'Ilyes Bellemare', 'ibellemare@protonmail.com']
# ['mc605', 563, 'Marsalis Colaianni', 'mcolaianni@yahoo.com']
# ['dg103', 65, 'Darnell Goodman', 'dgoodman@live.com']
# ['sd529', 563, 'Shay Daniel', 'sdaniel@yandex.com']
# ['ac329', 1911, 'Alessandro Correale', 'acorreale@yandex.com']
# ['nw931', 65, 'Natale Wallace', 'nwallace@outlook.com']
# ['ma304', 65, 'Michale Adenauer', 'madenauer@protonmail.com']
# ['da603', 65, 'Dietlinde Ayotte', 'dayotte@yahoo.com']
# ['mg138', 968, 'Mikki Guyard', 'mguyard@outlook.com']
# ['ac101', 1114, 'Alder Carnaghi', 'acarnaghi@yandex.com']
# ['nw842', 65, 'Nada Workman', 'nworkman@yahoo.com']
# ['bh208', 65, 'Benvolio Howe', 'bhowe@gmail.com']
# ['bh308', 65, 'Burma Hintzen', 'bhintzen@live.com']
# ['mm312', 65, 'Mirko Melchiori', 'mmelchiori@live.com']
# ['lh971', 65, 'Leny Harper', 'lharper@outlook.com']
# ['se114', 563, 'Scirocco Ellison', 'sellison@yahoo.com']
# ['bh284', 65, 'Buena Hellewege', 'bhellewege@yahoo.com']
# ['kc189', 563, 'Kanesha Correale', 'kcorreale@live.com']
# ['rf869', 1114, 'Renate Faulkner', 'rfaulkner@outlook.com']
# ['mg199', 65, 'Mohamed Gamble', 'mgamble@live.com']
# ['lb962', 65, 'Laronda Brossard', 'lbrossard@protonmail.com']
# ['db172', 1114, 'Derek Bresciani', 'dbresciani@outlook.com']
# ['sf770', 1572, 'Silvio Feld', 'sfeld@live.com']
# ['np731', 563, 'Noah Peroni', 'nperoni@outlook.com']
# ['ma765', 65, 'Medard Andrews', 'mandrews@gmail.com']
# ['at430', 65, 'Albane Tillman', 'atillman@yahoo.com']
# ['nh902', 65, 'Nathanial Heinrichs', 'nheinrichs@protonmail.com']
# ['mr954', 968, 'Margeret Rocheleau', 'mrocheleau@protonmail.com']
# ['ad976', 65, 'Alex Dominguez', 'adominguez@yandex.com']
# ['ea132', 65, 'Elario Avery', 'eavery@yahoo.com']
# ['dg632', 65, 'Delila Gros', 'dgros@yahoo.com']
# ['ap998', 968, 'Annalee Patel', 'apatel@protonmail.com']
# ['tp324', 563, 'Trudy Paoletta', 'tpaoletta@gmail.com']
# ['ra997', 563, 'Rayan Alston', 'ralston@yahoo.com']
# ['dl230', 563, 'Daniel Larson', 'dlarson@yahoo.com']
# ['rh438', 65, 'Raelene Horowitz', 'rhorowitz@outlook.com']
# ['ra521', 65, 'Rolanda Aubry', 'raubry@gmail.com']
# ['ct232', 1114, 'Chevy Traino', 'ctraino@outlook.com']
# ['pk248', 65, 'Perry Knox', 'pknox@gmail.com']
# ['sd478', 65, 'Shu Dennis', 'sdennis@gmail.com']
# ['gd604', 238, 'Grethe Derrick', 'gderrick@live.com']
# ['vb562', 1911, 'Vadim Baudoin', 'vbaudoin@yahoo.com']
# ['rt274', 1572, 'Ruggero Tucker', 'rtucker@gmail.com']
# ['wv265', 238, 'Wen Voigt', 'wvoigt@outlook.com']
# ['vv260', 65, 'Viktoria Verrier', 'vverrier@yandex.com']
# ['jr651', 1572, 'Janna Rando', 'jrando@protonmail.com']
# ['is444', 65, 'Isabella Salas', 'isalas@yandex.com']
# ['kb607', 948, 'Katherin Bumgarner', 'kbumgarner@live.com']
# ['ll538', 563, 'Lamar Lemelin', 'llemelin@yahoo.com']
# ['mc191', 65, 'Maribel Catone', 'mcatone@yandex.com']
# ['eb575', 65, 'Ezequiel Brandt', 'ebrandt@outlook.com']
# ['wl942', 238, 'Willie Launay', 'wlaunay@yandex.com']
# ['st133', 65, 'Safa Torchia', 'storchia@yahoo.com']
# ['cl196', 65, 'Clara Larson', 'clarson@yahoo.com']
# ['ws476', 968, 'Williams Sargent', 'wsargent@outlook.com']
# ['cb812', 1911, 'Cassondra Bret', 'cbret@outlook.com']
# ['cb535', 65, 'Catrin Barbarino', 'cbarbarino@gmail.com']
# ['jc627', 968, 'Jasmine Conley', 'jconley@gmail.com']
# ['kg987', 65, 'Keli Grosz', 'kgrosz@gmail.com']
# ['ec579', 65, 'Elbert Corriveau', 'ecorriveau@protonmail.com']
# ['ar298', 1572, 'August Raffo', 'araffo@outlook.com']
# ['af221', 65, 'Albertina Francis', 'afrancis@gmail.com']
# ['sj329', 968, 'Sergio Jager', 'sjager@live.com']
# ['dg117', 65, 'Dillon Guertin', 'dguertin@live.com']
# ['dc370', 1572, 'Diedrich Colantuono', 'dcolantuono@protonmail.com']
# ['zb278', 1114, 'Zahra Briggs', 'zbriggs@live.com']
# ['cl760', 1572, 'Charlsie Landry', 'clandry@outlook.com']
# ['jc156', 65, 'Jordon Cianci', 'jcianci@protonmail.com']
# ['as179', 1572, 'Alvin Shaw', 'ashaw@yandex.com']
# ['ip107', 65, 'Iban Petersen', 'ipetersen@gmail.com']
# ['rc580', 65, 'Ramiro Chevalier', 'rchevalier@yahoo.com']
# ['fs682', 563, 'Floyd Savoia', 'fsavoia@protonmail.com']
# ['nv909', 65, 'Nathalie Velez', 'nvelez@yandex.com']
# ['ms790', 65, 'Marianne Sweeney', 'msweeney@gmail.com']
# ['od761', 65, 'Orabella Dahl', 'odahl@gmail.com']
# ['mf156', 65, 'Maryanna Ferreira', 'mferreira@outlook.com']
# ['as164', 65, 'Arnetta Sarra', 'asarra@yahoo.com']
# ['vj589', 563, 'Vonn Juarez', 'vjuarez@protonmail.com']
# ['lb130', 2284, 'Lino Barrett', 'lbarrett@live.com']
# ['sl700', 65, 'Simone Lang', 'slang@yandex.com']
# ['mc819', 1572, 'Myron Carrere', 'mcarrere@outlook.com']
# ['rm952', 65, 'Raleigh Marchini', 'rmarchini@protonmail.com']
# ['pg461', 910, 'Peter Guy', 'pguy@live.com']
# ['nh583', 3138, 'Nohlan Hubbard', 'nhubbard@outlook.com']
# ['pb241', 2510, 'Prima Beckert', 'pbeckert@gmail.com']
# ['gl120', 65, 'Gwenn Lehoux', 'glehoux@outlook.com']
# ['la505', 968, 'Louetta Andrews', 'landrews@yandex.com']
# ['aw399', 1572, 'Anton Wagner', 'awagner@yahoo.com']
# ['re335', 968, 'Roman Eichel', 'reichel@outlook.com']
# ['bb962', 65, 'Bianka Beaumont', 'bbeaumont@live.com']
# ['ka827', 1114, 'Kathyrn Arata', 'karata@outlook.com']
# ['vw359', 238, 'Verona Weeks', 'vweeks@protonmail.com']
# ['tb824', 563, 'Tao Becke', 'tbecke@gmail.com']
# ['hc237', 65, 'Herbert Costa', 'hcosta@yandex.com']
# ['as145', 65, 'Antoine Stokes', 'astokes@protonmail.com']
# ['hw326', 65, 'Helmuth West', 'hwest@gmail.com']
# ['ap397', 65, 'Amando Peters', 'apeters@yahoo.com']
# ['ss188', 65, 'Sidney Spezia', 'sspezia@gmail.com']
# ['el440', 65, 'Elwanda Lopez', 'elopez@live.com']
# ['aa862', 968, 'Achim Avila', 'aavila@gmail.com']
# ['eg547', 968, 'Elias Giehl', 'egiehl@gmail.com']
# ['bb801', 1572, 'Beltrano Brodeur', 'bbrodeur@outlook.com']
# ['le995', 563, 'Loren Esposito', 'lesposito@live.com']
# ['md256', 65, 'Mary Daniels', 'mdaniels@outlook.com']
# ['mj723', 65, 'Medard Jordan', 'mjordan@outlook.com']
# ['jf335', 968, 'Joseph Favre', 'jfavre@yandex.com']
# ['os747', 65, 'Ortensia Sodaro', 'osodaro@yahoo.com']
# ['hw746', 65, 'Harley Watts', 'hwatts@outlook.com']
# ['cd245', 65, 'Carl Dohman', 'cdohman@gmail.com']
# ['ld541', 1572, 'Lucia Danieli', 'ldanieli@live.com']
# ['rh153', 65, 'Reatha Horton', 'rhorton@protonmail.com']
# ['bh368', 65, 'Birgit Herzog', 'bherzog@protonmail.com']
# ['lb158', 65, 'Leina Buratti', 'lburatti@gmail.com']
# ['cs978', 65, 'Cristen Stone', 'cstone@protonmail.com']
# ['mf368', 2882, 'Maybell Foerstner', 'mfoerstner@protonmail.com']
# ['wd850', 65, 'Walda Duhaime', 'wduhaime@outlook.com']
# ['eb501', 65, 'Elyas Benigno', 'ebenigno@live.com']
# ['ac560', 238, 'Antonietta Cervantes', 'acervantes@gmail.com']
# ['ra717', 65, 'Robbie Ayers', 'rayers@protonmail.com']
# ['kb147', 65, 'Kim Breiner', 'kbreiner@gmail.com']
# ['ab885', 65, 'Arendt Boisson', 'aboisson@protonmail.com']
# ['sm804', 65, 'Soline Manni', 'smanni@yahoo.com']
# ['nn896', 1114, 'Nicostrato Nolan', 'nnolan@protonmail.com']
# ['nh517', 65, 'Norris Haber', 'nhaber@gmail.com']
# ['ks751', 948, 'Kizzie Schmidt', 'kschmidt@protonmail.com']
# ['op970', 65, 'Olivia Pata', 'opata@outlook.com']
# ['fl206', 65, 'Flavien Lopez', 'flopez@live.com']
# ['vb725', 65, 'Vanna Boyer', 'vboyer@protonmail.com']
# ['ah650', 65, 'Avery Hase', 'ahase@outlook.com']
# ['mp562', 65, 'Micheal Perret', 'mperret@gmail.com']
# ['ss542', 65, 'Sonje Sabatelli', 'ssabatelli@outlook.com']
# ['uy666', 1114, 'Urbano Yates', 'uyates@yahoo.com']
# ['rs149', 563, 'Reita Schulz', 'rschulz@protonmail.com']
# ['nc808', 1114, 'Nils Crane', 'ncrane@protonmail.com']
# ['cf496', 65, 'Calinda Flowers', 'cflowers@live.com']
# ['ia565', 948, 'Idell Avril', 'iavril@gmail.com']
# ['jp782', 65, 'Jost Persichetti', 'jpersichetti@yandex.com']
# ['mh715', 1114, 'Maribel Huff', 'mhuff@outlook.com']
# ['nt342', 1572, 'Napoleone Trujillo', 'ntrujillo@gmail.com']
# ['mr456', 1572, 'Marilou Richter', 'mrichter@live.com']
# ['ca746', 65, 'Carey Andolina', 'candolina@protonmail.com']
# ['cm505', 65, 'Carl Macias', 'cmacias@gmail.com']
# ['sd889', 1114, 'Sylvana Derrick', 'sderrick@yahoo.com']
# ['bs934', 1114, 'Bryant Serres', 'bserres@live.com']
# ['ra567', 1114, 'Raffaela Allison', 'rallison@yahoo.com']
# ['rl204', 968, 'Remigio Lemelin', 'rlemelin@live.com']
# ['cc259', 1572, 'Cecil Camerino', 'ccamerino@live.com']
# ['sb553', 65, 'Spencer Browning', 'sbrowning@live.com']
# ['cg125', 65, 'Christof Graham', 'cgraham@gmail.com']
# ['qb899', 563, 'Quentin Brose', 'qbrose@yandex.com']
# ['ff220', 65, 'Federica Foulon', 'ffoulon@protonmail.com']
# ['hg196', 65, 'Hung Gengo', 'hgengo@gmail.com']
# ['sb625', 563, 'Shaina Beyersdorf', 'sbeyersdorf@outlook.com']
# ['pt119', 563, 'Pasquale Tran', 'ptran@live.com']
# ['lc553', 563, 'Lorrine Cagnina', 'lcagnina@yahoo.com']
# ['rc275', 65, 'Rebbecca Copeland', 'rcopeland@protonmail.com']
# ['md340', 968, 'Malte Douglas', 'mdouglas@yandex.com']
# ['cc173', 1572, 'Clint Clayton', 'cclayton@live.com']
# ['gd567', 65, 'Gretel Dunkle', 'gdunkle@gmail.com']
# ['mb618', 968, 'Mehdi Boivin', 'mboivin@protonmail.com']
# ['gc276', 65, 'Girolamo Casa', 'gcasa@protonmail.com']
# ['dc510', 1572, 'Delicia Cameron', 'dcameron@live.com']
# ['ye524', 2488, 'Yoshie Estrada', 'yestrada@yandex.com']
# ['yd412', 910, 'Yasmin Dreher', 'ydreher@outlook.com']
# ['if272', 65, 'Ilan Felix', 'ifelix@outlook.com']
# ['lc645', 65, 'Leandro Camerino', 'lcamerino@protonmail.com']
# ['ef207', 968, 'Erline Flores', 'eflores@protonmail.com']
# ['dg835', 2284, 'Danae Gordon', 'dgordon@live.com']
# ['hb488', 968, 'Hahn Brose', 'hbrose@protonmail.com']
# ['lm201', 563, 'Lison Mauger', 'lmauger@outlook.com']
# ['pc883', 910, 'Paolo Ciccarelli', 'pciccarelli@protonmail.com']
# ['kw981', 563, 'Kirk Wheeler', 'kwheeler@live.com']
# ['mz620', 65, 'Mataya Zanelli', 'mzanelli@yahoo.com']
# ['hg644', 1572, 'Hubert Guy', 'hguy@protonmail.com']
# ['es569', 563, 'Edwin Savage', 'esavage@yahoo.com']
# ['wg259', 65, 'Wulf Geissler', 'wgeissler@outlook.com']
# ['es891', 1114, 'Erminia Saverino', 'esaverino@outlook.com']
# ['pn152', 1911, 'Porter Nguyen', 'pnguyen@yandex.com']
# ['em884', 563, 'Eugene Mcmillan', 'emcmillan@yandex.com']
# ['mj677', 1911, 'Martin Justice', 'mjustice@yandex.com']
# ['as403', 968, 'Alfred Seidel', 'aseidel@yahoo.com']
# ['sn755', 65, 'Savannah Nieves', 'snieves@protonmail.com']
# ['cd582', 1572, 'Collin Duke', 'cduke@yandex.com']
# ['rb866', 65, 'Reda Brauer', 'rbrauer@yahoo.com']
# ['jg570', 1572, 'Jutte Gobert', 'jgobert@outlook.com']
# ['tm126', 65, 'Tomi Mckinney', 'tmckinney@outlook.com']
# ['kh370', 65, 'Kim Hofer', 'khofer@outlook.com']
# ['cd370', 1114, 'Conrad Dupuy', 'cdupuy@live.com']
# ['al498', 1572, 'Axel Lona', 'alona@gmail.com']
# ['gb805', 65, 'Galileo Britt', 'gbritt@outlook.com']
# ['gh546', 1114, 'Gustavo Hoffman', 'ghoffman@gmail.com']
# ['mv360', 65, 'Madde Villard', 'mvillard@yandex.com']
# ['sm882', 563, 'Sebastiano Mellone', 'smellone@yandex.com']
# ['nl941', 1572, 'Nick Leonard', 'nleonard@outlook.com']
# ['nc986', 65, 'Nicholas Carey', 'ncarey@live.com']
# ['ej494', 968, 'Elise Janson', 'ejanson@protonmail.com']
# ['ib275', 1572, 'Isra Bordeleau', 'ibordeleau@gmail.com']
# ['fm950', 1572, 'Fabia Margo', 'fmargo@outlook.com']
# ['uh130', 1114, 'Uli Hintzen', 'uhintzen@protonmail.com']
# ['nl576', 1114, 'Nelia Legendre', 'nlegendre@protonmail.com']
# ['ba847', 1114, 'Bonito Albino', 'balbino@protonmail.com']
# ['hk769', 1114, 'Harland Kent', 'hkent@yahoo.com']
# ['ce152', 65, 'Chan English', 'cenglish@yahoo.com']
# ['ds307', 65, 'Diedrich Seidel', 'dseidel@yandex.com']
# ['ap892', 65, 'Amadeo Passamonte', 'apassamonte@yandex.com']
# ['al282', 65, 'Ava Lapierre', 'alapierre@yahoo.com']
# ['ch210', 1114, 'Cecilio Haney', 'chaney@outlook.com']
# ['eh215', 65, 'Evan Hudson', 'ehudson@yahoo.com']
# ['eb850', 65, 'Eugen Barreau', 'ebarreau@outlook.com']
# ['dg270', 65, 'Didier Guidetti', 'dguidetti@yahoo.com']
# ['ff566', 65, 'Fiore Flynn', 'fflynn@live.com']
# ['am384', 65, 'Audrea Mathews', 'amathews@yahoo.com']
# ['gz133', 910, 'Grover Zimmermann', 'gzimmermann@outlook.com']
# ['sb280', 2510, 'Siegfried Bastien', 'sbastien@protonmail.com']
# ['au559', 65, 'Armand Uliano', 'auliano@outlook.com']
# ['ah481', 563, 'Apollinare Hansen', 'ahansen@protonmail.com']
# ['rf512', 65, 'Royce Fox', 'rfox@outlook.com']
# ['ag245', 65, 'Anastacia Gabler', 'agabler@gmail.com']
# ['gw953', 65, 'Gertrud White', 'gwhite@protonmail.com']
# ['el392', 1114, 'Emeline Lupoli', 'elupoli@yahoo.com']
# ['ng985', 563, 'Norma Gallegos', 'ngallegos@yahoo.com']
# ['wj382', 65, 'Walter Jordan', 'wjordan@live.com']
# ['ba575', 563, 'Bryanna Aue', 'baue@protonmail.com']
# ['eg561', 65, 'Emmerich Gobeil', 'egobeil@protonmail.com']
# ['lm964', 1572, 'Lauren Mazzo', 'lmazzo@live.com']
# ['sb431', 65, 'Severo Beasley', 'sbeasley@yahoo.com']
# ['do639', 1572, 'Delmar Owen', 'dowen@protonmail.com']
# ['sk460', 1114, 'Swanhild Kirk', 'skirk@outlook.com']
# ['rg322', 563, 'Ruggiero Geiszler', 'rgeiszler@live.com']
# ['dd765', 65, 'Dede Durocher', 'ddurocher@gmail.com']
# ['gr869', 1572, 'Gregory Raspa', 'graspa@yahoo.com']
# ['kb523', 65, 'Kim Ball', 'kball@protonmail.com']
# ['lm458', 65, 'Lionel Montgomery', 'lmontgomery@gmail.com']
# ['el995', 65, 'Emil Lane', 'elane@protonmail.com']
# ['ag183', 1572, 'Alessandrina Goebel', 'agoebel@live.com']
# ['ld726', 65, 'Leland Derasmo', 'lderasmo@yandex.com']
# ['kr437', 563, 'Klara Reynolds', 'kreynolds@live.com']
# ['da484', 65, 'Del Acker', 'dacker@protonmail.com']
# ['an639', 65, 'Angelena Nardone', 'anardone@gmail.com']
# ['mp433', 563, 'Marcos Pomerleau', 'mpomerleau@protonmail.com']
# ['be701', 1572, 'Burt Ellis', 'bellis@yahoo.com']
# ['jb183', 1114, 'Jasmin Blanchard', 'jblanchard@yandex.com']
# ['kh101', 1911, 'Kamil Heinrich', 'kheinrich@yahoo.com']
# ['mf245', 563, 'Maurizia Ferrand', 'mferrand@outlook.com']
# ['js289', 65, 'Jere Spaziano', 'jspaziano@yandex.com']
# ['up926', 65, 'Uschi Parks', 'uparks@yahoo.com']
# ['ld381', 1572, 'Lucrecia Delgado', 'ldelgado@protonmail.com']
# ['mc308', 65, 'Moritz Cooper', 'mcooper@protonmail.com']
# ['lc522', 1114, 'Liborio Cabana', 'lcabana@protonmail.com']
# ['dp392', 1114, 'Deetta Passarelli', 'dpassarelli@live.com']
# ['ac362', 1572, 'Antonio Compton', 'acompton@yahoo.com']
# ['nd561', 65, 'Nina Duncan', 'nduncan@yandex.com']
# ['fh314', 65, 'Francois Heinrichs', 'fheinrichs@yandex.com']
# ['sc323', 1572, 'Serafino Carton', 'scarton@protonmail.com']
# ['ec717', 65, 'Emerson Ciminelli', 'eciminelli@live.com']
# ['rl688', 65, 'Robin Lamb', 'rlamb@protonmail.com']
# ['uy750', 1114, 'Ulrika Yang', 'uyang@yahoo.com']
# ['nk412', 65, 'Nolann Klein', 'nklein@outlook.com']
# ['ap726', 65, 'Annibale Pierre', 'apierre@outlook.com']
# ['dr773', 1114, 'Denis Racioppi', 'dracioppi@live.com']
# ['ag727', 65, 'Arden Griffin', 'agriffin@yahoo.com']
# ['ob153', 65, 'Ottila Bruce', 'obruce@yahoo.com']
# ['td769', 910, 'Tancredo Dreschner', 'tdreschner@yahoo.com']
# ['cf164', 910, 'Carlos Fiocca', 'cfiocca@yandex.com']
# ['xb511', 1114, 'Xanthippe Barrett', 'xbarrett@gmail.com']
# ['mg697', 1114, 'Mayron Glenn', 'mglenn@protonmail.com']
# ['ab343', 65, 'Aniello Brant', 'abrant@protonmail.com']
# ['wr830', 1572, 'Willard Renard', 'wrenard@live.com']
# ['js847', 65, 'Jodee Savelli', 'jsavelli@protonmail.com']
# ['rg452', 65, 'Robert Glover', 'rglover@yahoo.com']
# ['lr201', 563, 'Loretta Rutledge', 'lrutledge@protonmail.com']
# ['jq602', 563, 'Jerica Quentin', 'jquentin@live.com']
# ['vw742', 1114, 'Vanna Winters', 'vwinters@yandex.com']
# ['ma775', 1572, 'Mila Abraham', 'mabraham@gmail.com']
# ['ms114', 65, 'Maida Sergent', 'msergent@outlook.com']
# ['bh610', 563, 'Belvedere Humphrey', 'bhumphrey@protonmail.com']
# ['ae528', 563, 'Arletha Engel', 'aengel@outlook.com']
# ['ec370', 968, 'Ernie Chiappini', 'echiappini@protonmail.com']
# ['mh322', 65, 'Melyna Hutchinson', 'mhutchinson@yahoo.com']
# ['aa738', 968, 'Annetta Andreas', 'aandreas@outlook.com']
# ['cq458', 910, 'Carson Quenneville', 'cquenneville@live.com']
# ['lp143', 1572, 'Lashon Patalano', 'lpatalano@protonmail.com']
# ['ip230', 1114, 'Ilsa Patrick', 'ipatrick@live.com']
# ['cw810', 65, 'Canon Wheeler', 'cwheeler@live.com']
# ['rd198', 563, 'Russel Duriez', 'rduriez@outlook.com']
# ['ic683', 65, 'Isaias Cherico', 'icherico@yahoo.com']
# ['wm615', 563, 'Waldeburg Mills', 'wmills@gmail.com']
# ['ls953', 65, 'Lilie Simpson', 'lsimpson@yandex.com']
# ['fj322', 563, 'Floritzel Jollenbeck', 'fjollenbeck@yandex.com']
# ['ld699', 65, 'Logan Desmarais', 'ldesmarais@yandex.com']
# ['pm788', 968, 'Peter Maldonado', 'pmaldonado@live.com']
# ['dm569', 1572, 'Delano Molina', 'dmolina@yandex.com']
# ['rt816', 65, 'Rossella Thomas', 'rthomas@yahoo.com']
# ['jd575', 238, 'Jeffrey Dupuy', 'jdupuy@live.com']
# ['zb283', 968, 'Zenia Bizzaro', 'zbizzaro@live.com']
# ['jp468', 65, 'Janna Payne', 'jpayne@yahoo.com']
# ['cg793', 563, 'Coco Grosse', 'cgrosse@protonmail.com']
# ['gp711', 65, 'Guy Peter', 'gpeter@outlook.com']
# ['pc765', 563, 'Parker Calandro', 'pcalandro@protonmail.com']
# ['sl534', 563, 'Sander Lott', 'slott@outlook.com']
# ['yv989', 65, 'Yael Villarreal', 'yvillarreal@yandex.com']
# ['mf798', 65, 'Mia Feigenbaum', 'mfeigenbaum@gmail.com']
# ['td407', 65, 'Thomas Davi', 'tdavi@yahoo.com']
# ['tg953', 968, 'Tobias Grant', 'tgrant@gmail.com']
# ['kc148', 65, 'Klarissa Carver', 'kcarver@protonmail.com']
# ['cs309', 563, 'Cassi Serrano', 'cserrano@outlook.com']
# ['mt354', 1572, 'Margrett Tierno', 'mtierno@yahoo.com']
# ['hw981', 968, 'Hellmuth Warren', 'hwarren@yandex.com']
# ['sk249', 65, 'Sabri Knight', 'sknight@yahoo.com']
# ['ud288', 65, 'Uberta Doyle', 'udoyle@protonmail.com']
# ['lb533', 65, 'Leida Buffo', 'lbuffo@yandex.com']
# ['bc627', 1572, 'Burt Colon', 'bcolon@gmail.com']
# ['sv404', 948, 'Sabine Velazquez', 'svelazquez@yandex.com']
# ['ab517', 563, 'Ayman Bocker', 'abocker@gmail.com']
# ['ta342', 1114, 'Teofilo Alarie', 'talarie@gmail.com']
# ['ja317', 1572, 'Jere Armellino', 'jarmellino@yahoo.com']
# ['rc984', 2882, 'Rudy Chase', 'rchase@gmail.com']
# ['mc890', 1572, 'Miles Copeland', 'mcopeland@yahoo.com']
# ['lp216', 65, 'Luigi Pasquarelli', 'lpasquarelli@gmail.com']
# ['fo113', 65, 'Federico Odom', 'fodom@protonmail.com']
# ['mb739', 65, 'Medard Berg', 'mberg@protonmail.com']
# ['gp648', 968, 'Geron Pichette', 'gpichette@yahoo.com']
# ['mr769', 65, 'Mariyah Romagnoli', 'mromagnoli@yandex.com']
# ['kp887', 1572, 'Keneth Pacheco', 'kpacheco@outlook.com']
# ['lb922', 1114, 'Linda Baum', 'lbaum@yandex.com']
# ['zr677', 65, 'Zahra Rousseau', 'zrousseau@gmail.com']
# ['bm219', 65, 'Biondello Mannella', 'bmannella@live.com']
# ['ah632', 65, 'Al Harris', 'aharris@protonmail.com']
# ['tr889', 65, 'Teodoro Rosa', 'trosa@yahoo.com']
# ['oh928', 1114, 'Odilia Hofer', 'ohofer@yahoo.com']
# ['rb570', 563, 'Romane Bruneau', 'rbruneau@protonmail.com']
# ['rb669', 1114, 'Ruggerio Brizzi', 'rbrizzi@outlook.com']
# ['ab395', 1572, 'Alwina Brune', 'abrune@outlook.com']
# ['cj317', 65, 'Charlie Jomphe', 'cjomphe@gmail.com']
# ['tr126', 968, 'Taddeo Ranallo', 'tranallo@outlook.com']
# ['bh500', 563, 'Boris Houston', 'bhouston@outlook.com']
# ['nw754', 65, 'Nicolaus Winkler', 'nwinkler@protonmail.com']
# ['nb415', 65, 'Nathanael Baudouin', 'nbaudouin@gmail.com']
# ['ic294', 968, 'Italo Cervelli', 'icervelli@live.com']
# ['jr674', 1114, 'Jackie Robertson', 'jrobertson@yandex.com']
# ['oh931', 65, 'Otis Hofmann', 'ohofmann@yahoo.com']
# ['jc510', 65, 'Joris Croteau', 'jcroteau@yahoo.com']
# ['gg408', 968, 'Geltrude Guidone', 'gguidone@protonmail.com']
# ['cb611', 1572, 'Christoper Baker', 'cbaker@yahoo.com']
# ['wj450', 65, 'Wendell Joseph', 'wjoseph@outlook.com']
# ['kb366', 65, 'Katinka Bader', 'kbader@yahoo.com']
# ['id932', 968, 'Idris Duprat', 'iduprat@gmail.com']
# ['pw185', 563, 'Ping Wright', 'pwright@yahoo.com']
# ['md753', 1114, 'Margarett Downs', 'mdowns@yahoo.com']
# ['db519', 968, 'Dietlind Buhr', 'dbuhr@outlook.com']
# ['vb592', 563, 'Verena Best', 'vbest@outlook.com']
# ['tl538', 65, 'Thimeo Leduc', 'tleduc@yahoo.com']
# ['se137', 968, 'Santuzza Esposito', 'sesposito@outlook.com']
# ['jf485', 563, 'Jenice Fuller', 'jfuller@gmail.com']
# ['nh755', 563, 'Nathaniel Hendricks', 'nhendricks@yahoo.com']
# ['ak859', 1572, 'Albert Kaiser', 'akaiser@outlook.com']
# ['tt425', 1114, 'Tamara Tanguay', 'ttanguay@yandex.com']
# ['cm443', 1114, 'Carson Mcguire', 'cmcguire@yandex.com']
# ['ih676', 65, 'Isaias Hutchinson', 'ihutchinson@outlook.com']
# ['mb336', 65, 'Milla Beckert', 'mbeckert@protonmail.com']
# ['da354', 238, 'Donielle Angelo', 'dangelo@yahoo.com']
# ['na435', 1572, 'Norberto Allen', 'nallen@protonmail.com']
# ['ar819', 65, 'Arminda Ratliff', 'aratliff@live.com']
# ['pw829', 910, 'Patrick Winkler', 'pwinkler@gmail.com']
# ['hb895', 1911, 'Hawa Beaudry', 'hbeaudry@gmail.com']
# ['mp964', 65, 'Marcoantonio Perretti', 'mperretti@live.com']
# ['em597', 65, 'Edmund Miranda', 'emiranda@yahoo.com']
# ['cr743', 65, 'Chet Rutledge', 'crutledge@yandex.com']
# ['sb664', 65, 'Sabina Buchholz', 'sbuchholz@outlook.com']
# ['nc766', 1572, 'Noam Camus', 'ncamus@outlook.com']
# ['iv865', 65, 'Immaculata Vanni', 'ivanni@yandex.com']
# ['kr139', 563, 'Kathern Raymond', 'kraymond@live.com']
# ['kp261', 65, 'Kathyrn Peck', 'kpeck@live.com']
# ['hb804', 65, 'Hilda Blumstein', 'hblumstein@protonmail.com']
# ['mb384', 968, 'Massima Baldocchi', 'mbaldocchi@protonmail.com']
# ['lp884', 1572, 'Lera Pearson', 'lpearson@protonmail.com']
# ['ae594', 65, 'Alleen Ellison', 'aellison@live.com']
# ['ta987', 1572, 'Tobias Althaus', 'talthaus@outlook.com']
# ['kd374', 65, 'Kim Desbiens', 'kdesbiens@yahoo.com']
# ['lt755', 65, 'Lucy Tringale', 'ltringale@gmail.com']
# ['ds585', 563, 'Dusti Sampson', 'dsampson@outlook.com']
# ['hm748', 238, 'Hyon Mcgowan', 'hmcgowan@outlook.com']
# ['bm320', 65, 'Benedikt Martin', 'bmartin@outlook.com']
# ['mm149', 65, 'Melina Montminy', 'mmontminy@yandex.com']
# ['nb639', 65, 'Nerezza Bottino', 'nbottino@yandex.com']
# ['cw520', 1572, 'Carter Washington', 'cwashington@yahoo.com']
# ['lb450', 65, 'Lashawnda Bradshaw', 'lbradshaw@yandex.com']
# ['ap187', 1114, 'Aldo Pohl', 'apohl@yandex.com']
# ['gt421', 968, 'Gaston Terrier', 'gterrier@protonmail.com']
# ['ep895', 968, 'Enric Pittman', 'epittman@live.com']
# ['wa701', 1572, 'Wonda Ayers', 'wayers@yahoo.com']
# ['yf490', 1114, 'Yasuko Fabel', 'yfabel@yandex.com']
# ['fl110', 65, 'Fredrik Lacroix', 'flacroix@live.com']
# ['lb870', 1114, 'Lucia Borgo', 'lborgo@protonmail.com']
# ['dg363', 65, 'Donatello Gordon', 'dgordon@protonmail.com']
# ['kb110', 1572, 'Kraig Busch', 'kbusch@live.com']
# ['fb424', 65, 'Fiona Brando', 'fbrando@protonmail.com']
# ['lw574', 65, 'Lisle Weaver', 'lweaver@live.com']
# ...
# ['sc764', 563, 'Selyan Cena', 'scena@outlook.com']
# ['ch995', 65, 'Cettina Hodge', 'chodge@outlook.com']
# ['sh598', 1572, 'Siu Haupt', 'shaupt@yandex.com']
# ['up415', 1114, 'Utta Paiement', 'upaiement@yandex.com']
# ['bb271', 1572, 'Bryan Bach', 'bbach@yandex.com']
# ['sw285', 563, 'Solal Wall', 'swall@protonmail.com']
# ['re497', 1114, 'Rodrigo England', 'rengland@protonmail.com']
# ['cb378', 65, 'Cherish Beringer', 'cberinger@live.com']
# ['kd222', 238, 'Kieth Daoust', 'kdaoust@yandex.com']
# ['mg992', 1572, 'Marouane Gaines', 'mgaines@protonmail.com']
# ['gc895', 65, 'Giordano Carroll', 'gcarroll@gmail.com']
# ['sa357', 948, 'Santo Althaus', 'salthaus@protonmail.com']
# ['br134', 910, 'Bert Ragot', 'bragot@live.com']
# ['mp679', 65, 'Matthias Panza', 'mpanza@gmail.com']
# ['lt411', 563, 'Lisandro Trevino', 'ltrevino@outlook.com']
# ['th567', 65, 'Tasha Hickman', 'thickman@yahoo.com']
# ['mh953', 563, 'Mike Hasenkamp', 'mhasenkamp@outlook.com']
# ['ws951', 65, 'Wilfred Schettini', 'wschettini@protonmail.com']
# ['ts277', 65, 'Thorello Stuart', 'tstuart@yandex.com']
# ['dh340', 65, 'Delta Hall', 'dhall@protonmail.com']
# ['rg479', 1572, 'Reuben Granier', 'rgranier@protonmail.com']
# ['cf328', 1114, 'Catharina Famiglietti', 'cfamiglietti@outlook.com']
# ['kd648', 65, 'Kalet Dominguez', 'kdominguez@gmail.com']
# ['wb294', 65, 'Wilton Behrend', 'wbehrend@protonmail.com']
# ['ah725', 238, 'Alan Horne', 'ahorne@gmail.com']
# ['rb358', 563, 'Rosabela Berger', 'rberger@outlook.com']
# ['ah548', 65, 'Ariane Huber', 'ahuber@yandex.com']
# ['lg389', 238, 'Luetta Goyette', 'lgoyette@protonmail.com']
# ['rp674', 968, 'Rudolf Perrotti', 'rperrotti@yahoo.com']
# ['aj756', 65, 'Axelle Juarez', 'ajuarez@gmail.com']
# ['em764', 1114, 'Egiodeo Maldonado', 'emaldonado@live.com']
# ['mh620', 1114, 'Mayola Haber', 'mhaber@live.com']
# ['sd769', 948, 'Shondra Despres', 'sdespres@yahoo.com']
# ['lf361', 65, 'Laura Falconi', 'lfalconi@yahoo.com']
# ['aj895', 948, 'Adama Justice', 'ajustice@yahoo.com']
# ['ab566', 563, 'Ampelio Bray', 'abray@protonmail.com']
# ['mv331', 65, 'Mikel Vogt', 'mvogt@outlook.com']
# ['ma879', 968, 'Medard Amabile', 'mamabile@outlook.com']
# ['ak873', 65, 'Amandine Key', 'akey@protonmail.com']
# ['rf484', 563, 'Raelene Falkenrath', 'rfalkenrath@yandex.com']
# ['mg371', 2284, 'Mikel Guilbaud', 'mguilbaud@live.com']
# ['ck475', 1911, 'Crocifissa Kirk', 'ckirk@gmail.com']
# ['tg594', 65, 'Tijuana Gros', 'tgros@gmail.com']
# ['ba226', 948, 'Bertram Auge', 'bauge@protonmail.com']
# ['sd852', 65, 'Seraphine Dentice', 'sdentice@live.com']
# ['sh663', 1911, 'Sara Hale', 'shale@live.com']
# ['nc492', 65, 'Natka Compton', 'ncompton@yahoo.com']
# ['gc903', 1572, 'Gregorio Carver', 'gcarver@live.com']
# ['ml364', 1911, 'Marc Lagarde', 'mlagarde@yandex.com']
# ['tf326', 563, 'Tabea Fera', 'tfera@yandex.com']
# ['bm501', 968, 'Bilal Maldonado', 'bmaldonado@yahoo.com']
# ['ls512', 65, 'Lisa Stokes', 'lstokes@protonmail.com']
# ['mf732', 1114, 'Mary Fenstermacher', 'mfenstermacher@gmail.com']
# ['tb656', 1572, 'Thanh Bonnefoy', 'tbonnefoy@outlook.com']
# ['mr562', 65, 'Medwin Roti', 'mroti@gmail.com']
# ['jl243', 65, 'Jeremy Logan', 'jlogan@yandex.com']
# ['lg207', 1572, 'Lyle Gehring', 'lgehring@protonmail.com']
# ['rt944', 563, 'Rufina Torres', 'rtorres@live.com']
# ['cb680', 65, 'Celian Bocker', 'cbocker@gmail.com']
# ['eb126', 65, 'Ettore Barreau', 'ebarreau@protonmail.com']
# ['cg645', 1114, 'Chae Golden', 'cgolden@protonmail.com']
# ['ec667', 65, 'Elisabeth Cameron', 'ecameron@yahoo.com']
# ['cb820', 65, 'Circinus Bocker', 'cbocker@live.com']
# ['em670', 65, 'Ezio Mary', 'emary@protonmail.com']
# ['rb630', 65, 'Romeo Brock', 'rbrock@protonmail.com']
# ['ks463', 65, 'Kamil Scholz', 'kscholz@live.com']
# ['gc111', 968, 'Gilda Cervi', 'gcervi@live.com']
# ['pt319', 968, 'Pearlene Terrell', 'pterrell@live.com']
# ['ae173', 1911, 'Achim Enns', 'aenns@outlook.com']
# ['ld623', 563, 'Lisa Dussault', 'ldussault@outlook.com']
# ['gs737', 563, 'Genevra Salas', 'gsalas@yahoo.com']
# ['cp181', 563, 'Coy Perry', 'cperry@yandex.com']
# ['dh987', 65, 'Duncan Herzog', 'dherzog@outlook.com']
# ['md387', 65, 'Merane Deslauriers', 'mdeslauriers@gmail.com']
# ['cg966', 563, 'Calvino Greene', 'cgreene@outlook.com']
# ['tt327', 563, 'Tuyet Turner', 'tturner@outlook.com']
# ['wf635', 65, 'Wynell Fiedler', 'wfiedler@yandex.com']
# ['lv941', 65, 'Lise Vultaggio', 'lvultaggio@outlook.com']
# ['wd119', 65, 'Wernher Daneau', 'wdaneau@yahoo.com']
# ['rc591', 238, 'Romy Canepa', 'rcanepa@live.com']
# ['jd259', 65, 'Jarvis Delacruz', 'jdelacruz@outlook.com']
# ['tm253', 65, 'Tobias Massimino', 'tmassimino@live.com']
# ['kl540', 1572, 'Kais Luna', 'kluna@protonmail.com']
# ['bf495', 1572, 'Berengar Fox', 'bfox@yahoo.com']
# ['aj224', 1114, 'Anamaria Joly', 'ajoly@live.com']
# ['hs471', 1114, 'Herbert Short', 'hshort@yandex.com']
# ['mp627', 65, 'Michael Prince', 'mprince@yahoo.com']
# ['vh761', 238, 'Venecia Hutmacher', 'vhutmacher@yahoo.com']
# ['rb689', 1572, 'Rick Bidault', 'rbidault@yahoo.com']
# ['mb886', 65, 'Malika Biviano', 'mbiviano@live.com']
# ['ls624', 2882, 'Leopold Slater', 'lslater@yandex.com']
# ['gh920', 1572, 'Giovanni Hayden', 'ghayden@live.com']
# ['rd784', 563, 'Ravenna Dieter', 'rdieter@gmail.com']
# ['lc491', 563, 'Lilli Capponi', 'lcapponi@protonmail.com']
# ['ma101', 65, 'Mahamadou Anderson', 'manderson@outlook.com']
# ['lh189', 65, 'Luciana Harrison', 'lharrison@gmail.com']
# ['fm990', 65, 'Foster Moisan', 'fmoisan@live.com']
# ['tc170', 968, 'Thomas Calitri', 'tcalitri@outlook.com']
# ['mg614', 1572, 'Margot Galloway', 'mgalloway@live.com']
# ['fv461', 65, 'Fiorenzo Velez', 'fvelez@yandex.com']
# ['wd286', 968, 'Wallace Duclos', 'wduclos@yahoo.com']
# ['sg911', 65, 'Sieglinde Guglielmetti', 'sguglielmetti@outlook.com']
# ['ab876', 65, 'Aja Best', 'abest@gmail.com']
# ['vl327', 563, 'Vaughn Legendre', 'vlegendre@yahoo.com']
# ['fv315', 968, 'Ferrand Vega', 'fvega@yandex.com']
# ['df903', 65, 'Dario Flater', 'dflater@live.com']
# ['cs150', 65, 'Capricia Sutton', 'csutton@protonmail.com']
# ['pb637', 1572, 'Phebe Bentley', 'pbentley@live.com']
# ['ag422', 65, 'Ardelle Gerber', 'agerber@yandex.com']
# ['kc637', 65, 'Karlheinz Cloarec', 'kcloarec@outlook.com']
# ['cb123', 65, 'Carmine Bird', 'cbird@outlook.com']
# ['rw927', 65, 'Rey Wade', 'rwade@yandex.com']
# ['jg833', 65, 'Janeth Geier', 'jgeier@yahoo.com']
# ['is534', 1572, 'Isolde Savage', 'isavage@gmail.com']
# ['mt153', 1572, 'Morgan Testo', 'mtesto@outlook.com']
# ['ba223', 563, 'Beppe Adkins', 'badkins@yandex.com']
# ['nl119', 65, 'Nicolaus Lopez', 'nlopez@yandex.com']
# ['dh749', 65, 'Dolce Houston', 'dhouston@outlook.com']
# ['gm326', 65, 'Gaylene Mcfadden', 'gmcfadden@gmail.com']
# ['kj739', 563, 'Kieth Janson', 'kjanson@protonmail.com']
# ['bj667', 1572, 'Beate Jolin', 'bjolin@yandex.com']
# ['rm779', 968, 'Reda Mascioli', 'rmascioli@yandex.com']
# ['eb329', 65, 'Elizabetta Beck', 'ebeck@yandex.com']
# ['am471', 1114, 'Ayana Medina', 'amedina@outlook.com']
# ['nw219', 1911, 'Nisha Wolf', 'nwolf@yandex.com']
# ['gd671', 238, 'Guido Dumoulin', 'gdumoulin@protonmail.com']
# ['ah110', 1572, 'Ashanti Hertz', 'ahertz@yandex.com']
# ['kc355', 563, 'Kena Caruso', 'kcaruso@protonmail.com']
# ['eh924', 968, 'Emerich Haynes', 'ehaynes@yandex.com']
# ['oo114', 968, 'Olivia Oliver', 'ooliver@outlook.com']
# ['nk967', 563, 'Norina Krause', 'nkrause@yandex.com']
# ['jc819', 1572, 'Jonathan Collet', 'jcollet@protonmail.com']
# ['nn320', 65, 'Noemi Nunez', 'nnunez@protonmail.com']
# ['lg552', 1572, 'Leelou Graham', 'lgraham@protonmail.com']
# ['cc964', 65, 'Camelia Carver', 'ccarver@yahoo.com']
# ['ts942', 65, 'Tomika Salce', 'tsalce@outlook.com']
# ['bh143', 65, 'Bethold Hendricks', 'bhendricks@live.com']
# ['as753', 1114, 'Adamo Schumacher', 'aschumacher@outlook.com']
# ['bb331', 65, 'Bill Bisso', 'bbisso@gmail.com']
# ['df172', 1911, 'Dorian Fitzgerald', 'dfitzgerald@yandex.com']
# ['gg603', 948, 'Gert Gill', 'ggill@protonmail.com']
# ['ag647', 65, 'Aria Grimard', 'agrimard@yahoo.com']
# ['fs375', 65, 'Frances Sperduto', 'fsperduto@protonmail.com']
# ['gs273', 1572, 'Georgann Salazar', 'gsalazar@gmail.com']
# ['fm198', 968, 'Franz Moreno', 'fmoreno@outlook.com']
# ['lc968', 1572, 'Laquanda Chan', 'lchan@protonmail.com']
# ['rp610', 1911, 'Russel Pecora', 'rpecora@gmail.com']
# ['xg514', 238, 'Xandra Gonzalez', 'xgonzalez@yandex.com']
# ['pm146', 563, 'Pamila Mouton', 'pmouton@gmail.com']
# ['cn376', 65, 'Christeen Nalbone', 'cnalbone@protonmail.com']
# ['us202', 65, 'Ugo Simpson', 'usimpson@outlook.com']
# ['ih997', 1114, 'Izia Hayden', 'ihayden@outlook.com']
# ['jh894', 1572, 'Jiordano Hertz', 'jhertz@protonmail.com']
# ['em778', 65, 'Elwood Moret', 'emoret@yandex.com']
# ['ez786', 65, 'Edyth Zanon', 'ezanon@yandex.com']
# ['ff753', 968, 'Felicia Fitzgerald', 'ffitzgerald@yahoo.com']
# ['jh308', 65, 'Jessica Horton', 'jhorton@gmail.com']
# ['ba496', 65, 'Borachio Achterberg', 'bachterberg@gmail.com']
# ['jr856', 65, 'Jed Roussy', 'jroussy@yandex.com']
# ['mg154', 65, 'Mitch Gelsomino', 'mgelsomino@yandex.com']
# ['hr729', 238, 'Heinz Rojas', 'hrojas@live.com']
# ['rw227', 65, 'Ryan Ware', 'rware@yahoo.com']
# ['gg113', 65, 'Giovanni Gerst', 'ggerst@yahoo.com']
# ['ml808', 1114, 'Marlana Lienard', 'mlienard@yandex.com']
# ['kv629', 1114, 'Kelle Vida', 'kvida@outlook.com']
# ['cs160', 1572, 'Clelia Santos', 'csantos@yandex.com']
# ['rd730', 1911, 'Rosina Denzel', 'rdenzel@live.com']
# ['gn399', 1911, 'Geert Nieves', 'gnieves@gmail.com']
# ['dk455', 65, 'Dusty Klein', 'dklein@protonmail.com']
# ['rm859', 1572, 'Roxy Martinet', 'rmartinet@yandex.com']
# ['lm837', 1572, 'Ladislaus Mcgee', 'lmcgee@live.com']
# ['av407', 563, 'Adrian Valencia', 'avalencia@gmail.com']
# ['as284', 968, 'Angelina Sommer', 'asommer@yandex.com']
# ['tr700', 563, 'Tristan Rini', 'trini@yahoo.com']
# ['rl632', 1572, 'Ramonita Lewis', 'rlewis@yandex.com']
# ['sh478', 968, 'Savina Harman', 'sharman@gmail.com']
# ['ss259', 65, 'Shannon Sergent', 'ssergent@yahoo.com']
# ['ym376', 1911, 'Yong Morgano', 'ymorgano@yahoo.com']
# ['eh807', 1114, 'Eberhard Hoover', 'ehoover@gmail.com']
# ['lp300', 563, 'Loann Patel', 'lpatel@yahoo.com']
# ['sl321', 1572, 'Simonetta Lehmann', 'slehmann@live.com']
# ['db506', 563, 'Darwin Beaumont', 'dbeaumont@yahoo.com']
# ['oc694', 65, 'Odell Carlin', 'ocarlin@outlook.com']
# ['ka567', 1572, 'Kristin Adams', 'kadams@outlook.com']
# ['ri837', 65, 'Riyad Irwin', 'rirwin@gmail.com']
# ['gg473', 1572, 'Gilda Groos', 'ggroos@gmail.com']
# ['ar944', 65, 'Andera Rolland', 'arolland@yahoo.com']
# ['lf592', 968, 'Laurine Ferguson', 'lferguson@yahoo.com']
# ['cb502', 910, 'Christian Bauer', 'cbauer@gmail.com']
# ['kh921', 1572, 'Kermit Humbert', 'khumbert@outlook.com']
# ['ci145', 1114, 'Carson Impastato', 'cimpastato@live.com']
# ['cr508', 2882, 'Cecilie Rodriguez', 'crodriguez@protonmail.com']
# ['af138', 563, 'Annalisa Feigenbaum', 'afeigenbaum@protonmail.com']
# ['mv493', 968, 'Marine Verona', 'mverona@live.com']
# ['ww245', 65, 'Walter Webster', 'wwebster@yandex.com']
# ['kf583', 65, 'Kristina Farrell', 'kfarrell@live.com']
# ['bh618', 65, 'Blaise Herbert', 'bherbert@protonmail.com']
# ['pp126', 65, 'Prima Pilote', 'ppilote@live.com']
# ['kf282', 910, 'Kevin Ford', 'kford@yahoo.com']
# ['hb505', 1911, 'Holland Brinkerhoff', 'hbrinkerhoff@live.com']
# ['rc421', 65, 'Rosabel Cardon', 'rcardon@protonmail.com']
# ['cc595', 65, 'Clifton Cicio', 'ccicio@yahoo.com']
# ['ms810', 948, 'Montrell Schmitt', 'mschmitt@outlook.com']
# ['cc343', 65, 'Clemente Chauvet', 'cchauvet@outlook.com']
# ['mv448', 65, 'Marcos Viel', 'mviel@outlook.com']
# ['ib668', 65, 'Idell Blackburn', 'iblackburn@gmail.com']
# ['hb393', 1572, 'Hermine Bates', 'hbates@yandex.com']
# ['ah345', 65, 'Armand Hall', 'ahall@live.com']
# ['jc355', 1572, 'Julian Cardenas', 'jcardenas@yandex.com']
# ['sf571', 65, 'Shon Frost', 'sfrost@live.com']
# ['dl914', 968, 'David Lebas', 'dlebas@protonmail.com']
# ['ag220', 1114, 'Angelina Guida', 'aguida@gmail.com']
# ['nh963', 65, 'Nicoletta Hood', 'nhood@protonmail.com']
# ['bb345', 65, 'Beata Bischoffs', 'bbischoffs@gmail.com']
# ['sp482', 968, 'Sonia Panozzo', 'spanozzo@protonmail.com']
# ['ac807', 1572, 'Albinia Colon', 'acolon@gmail.com']
# ['lp322', 65, 'Logan Pitts', 'lpitts@protonmail.com']
# ['th942', 65, 'Tom Hofmeister', 'thofmeister@outlook.com']
# ['lc707', 563, 'Lou Cordaro', 'lcordaro@outlook.com']
# ['ml646', 968, 'Meriem Lindsey', 'mlindsey@protonmail.com']
# ['ih987', 238, 'Imelda Haynes', 'ihaynes@yahoo.com']
# ['ah213', 1911, 'Annika Houk', 'ahouk@protonmail.com']
# ['nm664', 65, 'Natalya Marques', 'nmarques@yahoo.com']
# ['wb613', 65, 'William Botticelli', 'wbotticelli@protonmail.com']
# ['aa174', 65, 'Alix Adkins', 'aadkins@outlook.com']
# ['gw422', 65, 'Gianpaolo Wall', 'gwall@yahoo.com']
# ['bf209', 968, 'Bronwyn Fuchs', 'bfuchs@live.com']
# ['np290', 65, 'Neville Patenaude', 'npatenaude@yandex.com']
# ['rc255', 65, 'Rico Cervelli', 'rcervelli@protonmail.com']
# ['as439', 1572, 'Aramis Sutton', 'asutton@live.com']
# ['fh603', 65, 'Fulvio Hatfield', 'fhatfield@protonmail.com']
# ['od396', 968, 'Oswaldo Dirks', 'odirks@yahoo.com']
# ['rd571', 563, 'Raymond Despres', 'rdespres@protonmail.com']
# ['to793', 968, 'Titouan Olsen', 'tolsen@yandex.com']
# ['yp317', 563, 'Yee Pohl', 'ypohl@yandex.com']
# ['hm785', 65, 'Hilda Magnin', 'hmagnin@gmail.com']
# ['bb745', 65, 'Brunetta Battista', 'bbattista@protonmail.com']
# ['aj256', 65, 'Ali Johnson', 'ajohnson@yandex.com']
# ['gb612', 65, 'Garen Balestrieri', 'gbalestrieri@live.com']
# ['jg104', 1911, 'Jerald Gros', 'jgros@live.com']
# ['am940', 563, 'Ali Manzella', 'amanzella@yahoo.com']
# ['kl379', 968, 'Kunigunde Lawrence', 'klawrence@protonmail.com']
# ['jk118', 65, 'Jesper Kinney', 'jkinney@protonmail.com']
# ['fb822', 65, 'Fabrizia Beckert', 'fbeckert@outlook.com']
# ['hl483', 65, 'Hassie Lortie', 'hlortie@gmail.com']
# ['am522', 65, 'Amara Morrow', 'amorrow@live.com']
# ['yd385', 65, 'Yann Dudley', 'ydudley@gmail.com']
# ['pg994', 238, 'Patrizia Gerhardt', 'pgerhardt@gmail.com']
# ['ss878', 563, 'Sherilyn Salle', 'ssalle@outlook.com']
# ['jc530', 65, 'Judson Corda', 'jcorda@live.com']
# ['uc280', 65, 'Ulrich Casey', 'ucasey@yandex.com']
# ['yo890', 65, 'Yasmine Ortega', 'yortega@yandex.com']
# ['jl151', 1572, 'Julene Leroux', 'jleroux@live.com']
# ['tc958', 563, 'Terresa Conetta', 'tconetta@protonmail.com']
# ['bb468', 238, 'Benno Blankenship', 'bblankenship@outlook.com']
# ['ek984', 65, 'Elya Kemp', 'ekemp@gmail.com']
# ['tr337', 563, 'Tulio Richter', 'trichter@protonmail.com']
# ['dc332', 65, 'Damien Catalani', 'dcatalani@protonmail.com']
# ['lt266', 968, 'Lambert Taylor', 'ltaylor@outlook.com']
# ['jp331', 1911, 'Jesper Preston', 'jpreston@outlook.com']
# ['ch149', 65, 'Celso Habich', 'chabich@protonmail.com']
# ['ov932', 563, 'Owen Verdier', 'overdier@yandex.com']
# ['jg157', 65, 'Jacqueline Glover', 'jglover@gmail.com']
# ['lf543', 563, 'Lunette Fitzgerald', 'lfitzgerald@protonmail.com']
# ['ew441', 65, 'Enrichetta Wolff', 'ewolff@outlook.com']
# ['ll550', 65, 'Lera Lacroix', 'llacroix@protonmail.com']
# ['yh832', 968, 'Youna Herrera', 'yherrera@outlook.com']
# ['ag676', 65, 'Arnoldo Gabler', 'agabler@gmail.com']
# ['cm750', 563, 'Carolynn Marois', 'cmarois@yahoo.com']
# ['tc578', 65, 'Tamatha Caridi', 'tcaridi@gmail.com']
# ['xt124', 563, 'Xaviera Taylor', 'xtaylor@yandex.com']
# ['lh881', 968, 'Laetitia Hobbs', 'lhobbs@protonmail.com']
# ['bd768', 563, 'Bruno Dreher', 'bdreher@yandex.com']
# ['gm909', 65, 'Gidget Martins', 'gmartins@gmail.com']
# ['ec360', 563, 'Edda Ciambrone', 'eciambrone@live.com']
# ['dg792', 65, 'Donatien Grosz', 'dgrosz@yandex.com']
# ['cc155', 968, 'Claribel Collard', 'ccollard@gmail.com']
# ['bj789', 65, 'Beate Joseph', 'bjoseph@protonmail.com']
# ['ma252', 2488, 'Murray Archambault', 'marchambault@outlook.com']
# ['ll103', 563, 'Laine Lorino', 'llorino@protonmail.com']
# ['nb527', 1572, 'Nicolaus Black', 'nblack@gmail.com']
# ['ra872', 65, 'Ricciardo Acevedo', 'racevedo@live.com']
# ['ac509', 65, 'Adolfo Corriveau', 'acorriveau@yahoo.com']
# ['mh501', 65, 'Marco Hobbs', 'mhobbs@outlook.com']
# ['tb312', 65, 'Tamatha Bambach', 'tbambach@protonmail.com']
# ['st581', 65, 'Serita Thebault', 'sthebault@yandex.com']
# ['gf637', 563, 'Glenn Foerstner', 'gfoerstner@yahoo.com']
# ['rc983', 1114, 'Robt Collin', 'rcollin@outlook.com']
# ['cz381', 65, 'Corina Zappa', 'czappa@outlook.com']
# ['fg535', 65, 'Freeman Gibbs', 'fgibbs@outlook.com']

# %%
# Create a backers_df DataFrame with the following columns: 'backer_id','cf_id', 'name', and 'email'
# using the list of values lists. 
backers_df = pd.DataFrame(values, columns = column_names[0])
backers_df.head(10)
# Out:
#   backer_id  cf_id              name                  email
# 0     av166    968    Angelo Vincent      avincent@live.com
# 1     ha127    563     Hubert Arnold     harnold@yandex.com
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4     lh506    563        Lexie Hunt         lhunt@live.com
# 5     lh382    563     Lambert Huber        lhuber@live.com
# 6     em444    563        Emmy Morin        emorin@live.com
# 7     at582   1572     Armonda Trani        atrani@live.com
# 8     id772   1911        Ilana Duke      iduke@outlook.com
# 9     lw275     65     Leigha Wright       lwright@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_df.to_csv("backers_df.csv", encoding = 'utf8',index=False)

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 2: Use regex
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Extract the "backer_id", "cf_id", "name", and "email using regular expressions."
# 3. Create a new DataFrame with the retrieved data.
# 4. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backer_info_df2 = pd.read_csv("backer_info.csv")
backer_info_df2.head(10)
# Out:
#                                                                                           backer_info
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# 5           {"backer_id": "lh382", "cf_id": 563, "name": "Lambert Huber", "email": "lhuber@live.com"}
# 6              {"backer_id": "em444", "cf_id": 563, "name": "Emmy Morin", "email": "emorin@live.com"}
# 7          {"backer_id": "at582", "cf_id": 1572, "name": "Armonda Trani", "email": "atrani@live.com"}
# 8           {"backer_id": "id772", "cf_id": 1911, "name": "Ilana Duke", "email": "iduke@outlook.com"}
# 9           {"backer_id": "lw275", "cf_id": 65, "name": "Leigha Wright", "email": "lwright@live.com"}

# %%
# Extract the alpha-numeric "backer_id" from the backer_info column using a regex expression 
# and add it as a new column called "backer_id".
backer_info_df2['backer_id'] = backer_info_df2['backer_info'].str.extract('\"(\w+\d{3})\"')
backer_info_df2.head(10)
# Out:
#                                                                                           backer_info  \
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# 5           {"backer_id": "lh382", "cf_id": 563, "name": "Lambert Huber", "email": "lhuber@live.com"}
# 6              {"backer_id": "em444", "cf_id": 563, "name": "Emmy Morin", "email": "emorin@live.com"}
# 7          {"backer_id": "at582", "cf_id": 1572, "name": "Armonda Trani", "email": "atrani@live.com"}
# 8           {"backer_id": "id772", "cf_id": 1911, "name": "Ilana Duke", "email": "iduke@outlook.com"}
# 9           {"backer_id": "lw275", "cf_id": 65, "name": "Leigha Wright", "email": "lwright@live.com"}
#
#   backer_id
# 0     av166
# 1     ha127
# 2     lg794
# 3     tb566
# 4     lh506
# 5     lh382
# 6     em444
# 7     at582
# 8     id772
# 9     lw275

# %%
# Extract the two to four-digit "cf_id" number from the backer_info column. 
# and add it as a new column called "cf_id".
backer_info_df2['cf_id'] = backer_info_df2['backer_info'].str.extract('\:\s(\d{2,4})\,\s')
backer_info_df2.head(10)
# Out:
#                                                                                           backer_info  \
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# 5           {"backer_id": "lh382", "cf_id": 563, "name": "Lambert Huber", "email": "lhuber@live.com"}
# 6              {"backer_id": "em444", "cf_id": 563, "name": "Emmy Morin", "email": "emorin@live.com"}
# 7          {"backer_id": "at582", "cf_id": 1572, "name": "Armonda Trani", "email": "atrani@live.com"}
# 8           {"backer_id": "id772", "cf_id": 1911, "name": "Ilana Duke", "email": "iduke@outlook.com"}
# 9           {"backer_id": "lw275", "cf_id": 65, "name": "Leigha Wright", "email": "lwright@live.com"}
#
#   backer_id cf_id
# 0     av166   968
# 1     ha127   563
# 2     lg794    65
# 3     tb566   563
# 4     lh506   563
# 5     lh382   563
# 6     em444   563
# 7     at582  1572
# 8     id772  1911
# 9     lw275    65

# %%
# Extract the name from the backer_info column and add it as a new column called "name".
backer_info_df2['name'] = backer_info_df2['backer_info'].str.extract('\"(\w+\s\w+)\"')
backer_info_df2.head(10)
# Out:
#                                                                                           backer_info  \
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# 5           {"backer_id": "lh382", "cf_id": 563, "name": "Lambert Huber", "email": "lhuber@live.com"}
# 6              {"backer_id": "em444", "cf_id": 563, "name": "Emmy Morin", "email": "emorin@live.com"}
# 7          {"backer_id": "at582", "cf_id": 1572, "name": "Armonda Trani", "email": "atrani@live.com"}
# 8           {"backer_id": "id772", "cf_id": 1911, "name": "Ilana Duke", "email": "iduke@outlook.com"}
# 9           {"backer_id": "lw275", "cf_id": 65, "name": "Leigha Wright", "email": "lwright@live.com"}
#
#   backer_id cf_id              name
# 0     av166   968    Angelo Vincent
# 1     ha127   563     Hubert Arnold
# 2     lg794    65      Loris Goulet
# 3     tb566   563  Teodora Brunelli
# 4     lh506   563        Lexie Hunt
# 5     lh382   563     Lambert Huber
# 6     em444   563        Emmy Morin
# 7     at582  1572     Armonda Trani
# 8     id772  1911        Ilana Duke
# 9     lw275    65     Leigha Wright

# %%
# Extract the email from the backer_info column and add it as a new column called "email".
backer_info_df2['email'] = backer_info_df2['backer_info'].str.extract('\"(\w+\@\w+\.\w+)\"')
backer_info_df2.head(10)
# Out:
#                                                                                           backer_info  \
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# 5           {"backer_id": "lh382", "cf_id": 563, "name": "Lambert Huber", "email": "lhuber@live.com"}
# 6              {"backer_id": "em444", "cf_id": 563, "name": "Emmy Morin", "email": "emorin@live.com"}
# 7          {"backer_id": "at582", "cf_id": 1572, "name": "Armonda Trani", "email": "atrani@live.com"}
# 8           {"backer_id": "id772", "cf_id": 1911, "name": "Ilana Duke", "email": "iduke@outlook.com"}
# 9           {"backer_id": "lw275", "cf_id": 65, "name": "Leigha Wright", "email": "lwright@live.com"}
#
#   backer_id cf_id              name                  email
# 0     av166   968    Angelo Vincent      avincent@live.com
# 1     ha127   563     Hubert Arnold     harnold@yandex.com
# 2     lg794    65      Loris Goulet     lgoulet@yandex.com
# 3     tb566   563  Teodora Brunelli  tbrunelli@outlook.com
# 4     lh506   563        Lexie Hunt         lhunt@live.com
# 5     lh382   563     Lambert Huber        lhuber@live.com
# 6     em444   563        Emmy Morin        emorin@live.com
# 7     at582  1572     Armonda Trani        atrani@live.com
# 8     id772  1911        Ilana Duke      iduke@outlook.com
# 9     lw275    65     Leigha Wright       lwright@live.com

# %%
# Create a new DataFrame with the appropriate columns.
backer_info_df2 = backer_info_df2[["backer_id", "cf_id", "name", "email"]]
backer_info_df2.head(10)
# Out:
#   backer_id cf_id              name                  email
# 0     av166   968    Angelo Vincent      avincent@live.com
# 1     ha127   563     Hubert Arnold     harnold@yandex.com
# 2     lg794    65      Loris Goulet     lgoulet@yandex.com
# 3     tb566   563  Teodora Brunelli  tbrunelli@outlook.com
# 4     lh506   563        Lexie Hunt         lhunt@live.com
# 5     lh382   563     Lambert Huber        lhuber@live.com
# 6     em444   563        Emmy Morin        emorin@live.com
# 7     at582  1572     Armonda Trani        atrani@live.com
# 8     id772  1911        Ilana Duke      iduke@outlook.com
# 9     lw275    65     Leigha Wright       lwright@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_df.to_csv("backers_df_using_regrex.csv", encoding = 'utf8',index=False)

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.
backers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   backer_id  8175 non-null   object
#  1   cf_id      8175 non-null   int64
#  2   name       8175 non-null   object
#  3   email      8175 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 255.6+ KB

# %%
# Convert cf_id to an integer if necessary.
# 'cf_id' column is already in int64, no need to convert.
# backers_df['cf_id'].astype('int64') only needed if 'cf_id' column is not int64
backers_df['cf_id'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8175 entries, 0 to 8174
# Series name: cf_id
# Non-Null Count  Dtype
# --------------  -----
# 8175 non-null   int64
# dtypes: int64(1)
# memory usage: 64.0 KB

# %%
# Split the "name" column into "first_name" and "last_name" columns.
backers_df[['first_name','last_name']] = backers_df['name'].str.split(' ', n=1, expand = True)
backers_df.head(10)
# Out:
#   backer_id  cf_id              name                  email first_name  \
# 0     av166    968    Angelo Vincent      avincent@live.com     Angelo
# 1     ha127    563     Hubert Arnold     harnold@yandex.com     Hubert
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com      Loris
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com    Teodora
# 4     lh506    563        Lexie Hunt         lhunt@live.com      Lexie
# 5     lh382    563     Lambert Huber        lhuber@live.com    Lambert
# 6     em444    563        Emmy Morin        emorin@live.com       Emmy
# 7     at582   1572     Armonda Trani        atrani@live.com    Armonda
# 8     id772   1911        Ilana Duke      iduke@outlook.com      Ilana
# 9     lw275     65     Leigha Wright       lwright@live.com     Leigha
#
#   last_name
# 0   Vincent
# 1    Arnold
# 2    Goulet
# 3  Brunelli
# 4      Hunt
# 5     Huber
# 6     Morin
# 7     Trani
# 8      Duke
# 9    Wright

# %%
#  Drop the name column
del backers_df['name']

# Reorder the columns
backers_df = backers_df[["backer_id", "cf_id", "first_name", "last_name", "email"]]
backers_df.head(10)
# Out:
#   backer_id  cf_id first_name last_name                  email
# 0     av166    968     Angelo   Vincent      avincent@live.com
# 1     ha127    563     Hubert    Arnold     harnold@yandex.com
# 2     lg794     65      Loris    Goulet     lgoulet@yandex.com
# 3     tb566    563    Teodora  Brunelli  tbrunelli@outlook.com
# 4     lh506    563      Lexie      Hunt         lhunt@live.com
# 5     lh382    563    Lambert     Huber        lhuber@live.com
# 6     em444    563       Emmy     Morin        emorin@live.com
# 7     at582   1572    Armonda     Trani        atrani@live.com
# 8     id772   1911      Ilana      Duke      iduke@outlook.com
# 9     lw275     65     Leigha    Wright       lwright@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_df.to_csv("backers.csv", encoding = 'utf8',index=False)
